# %%
from IMPORTS import *
import pandas as pd
seed_value = 18
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Python311\Lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Python311\Lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
with open('WordEmbeddings/glove.840B.300d.pkl', 'rb') as fp:
    glove = pickle.load(fp)

# %% [markdown]
# # ATE

# %% [markdown]
# Reading ATE json files

# %%
ATE_train = None
ATE_test = None
ATE_val = None
with open("Task1\processed\ATE_train.json") as f1:
    ATE_train  = json.load(f1)

with open("Task1\processed\ATE_test.json") as f2:
    ATE_test = json.load(f2)

with open("Task1\processed\ATE_val.json") as f3:
    ATE_val = json.load(f3)

# %% [markdown]
# ATE Dataset

# %%
X_train_ate,Y_train_ate= create_train_test_val(ATE_train)
X_test_ate,Y_test_ate = create_train_test_val(ATE_test)
X_val_ate,Y_val_ate = create_train_test_val(ATE_val)

# %% [markdown]
# Tokenizing the ATE Dataset

# %%
X_train_ate_tokenized, toke = TokenCreator(X_train_ate,1)
X_test_ate_tokenized = TokenCreator(X_test_ate,0,tokenizer = toke)
X_val_ate_tokenized = TokenCreator(X_val_ate,0,tokenizer = toke)

Y_train_ate_tokenized,toke2 = TokenCreator(Y_train_ate,0)
Y_test_ate_tokenized = TokenCreator(Y_test_ate,0,tokenizer = toke2)
Y_val_ate_tokenized = TokenCreator(Y_val_ate,0,tokenizer = toke2)

# %% [markdown]
# Vocabulary of ATE

# %%
st1 = find_vocab(X_train_ate_tokenized)
vocab_size_ate  = len(st1) + 1 
vocab_size_ate
# Out:
# 2406

# %% [markdown]
# Padding ATE

# %%
X_padded_train = pad_sequences(X_train_ate_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_train = pad_sequences(Y_train_ate_tokenized, maxlen=100, padding="pre", truncating="post")

X_padded_test = pad_sequences(X_test_ate_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_test = pad_sequences(Y_test_ate_tokenized, maxlen=100, padding="pre", truncating="post")

X_padded_val = pad_sequences(X_val_ate_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_val = pad_sequences(Y_val_ate_tokenized, maxlen=100, padding="pre", truncating="post")

# %% [markdown]
# One hot encoding the ATE labels

# %%
Y_padded_train = to_categorical(Y_padded_train)
Y_padded_test = to_categorical(Y_padded_test)
Y_padded_val = to_categorical(Y_padded_val)

# %% [markdown]
# Assigning **ATE Glove** mapping

# %%
weights_ate_glove = np.zeros((vocab_size_ate, 300))

mapping_ate_glove = toke.word_index 
mapping_ate_glove
# Out:
# {'#UK': 1,
#  'the': 2,
#  '.': 3,
#  ',': 4,
#  'and': 5,
#  'it': 6,
#  'to': 7,
#  'i': 8,
#  'is': 9,
#  'a': 10,
#  'of': 11,
#  'for': 12,
#  'with': 13,
#  'that': 14,
#  'my': 15,
#  'you': 16,
#  'this': 17,
#  'was': 18,
#  'in': 19,
#  'not': 20,
#  'on': 21,
#  'very': 22,
#  'but': 23,
#  'computer': 24,
#  'use': 25,
#  'have': 26,
#  'great': 27,
#  'they': 28,
#  'laptop': 29,
#  "n't": 30,
#  'so': 31,
#  'has': 32,
#  'are': 33,
#  'battery': 34,
#  'had': 35,
#  'screen': 36,
#  ')': 37,
#  'be': 38,
#  'as': 39,
#  'all': 40,
#  '!': 41,
#  '(': 42,
#  "'s": 43,
#  'also': 44,
#  'me': 45,
#  'just': 46,
#  'easy': 47,
#  'when': 48,
#  'at': 49,
#  'or': 50,
#  'only': 51,
#  'which': 52,
#  'up': 53,
#  'life': 54,
#  'can': 55,
#  'windows': 56,
#  'than': 57,
#  'out': 58,
#  'if': 59,
#  'do': 60,
#  'after': 61,
#  'more': 62,
#  'keyboard': 63,
#  'would': 64,
#  'drive': 65,
#  'hard': 66,
#  'price': 67,
#  'from': 68,
#  'well': 69,
#  'because': 70,
#  'good': 71,
#  'one': 72,
#  'an': 73,
#  'like': 74,
#  'mac': 75,
#  'about': 76,
#  'quality': 77,
#  'its': 78,
#  'love': 79,
#  'get': 80,
#  'no': 81,
#  'software': 82,
#  'time': 83,
#  'even': 84,
#  'macbook': 85,
#  'will': 86,
#  'system': 87,
#  'apple': 88,
#  'other': 89,
#  'there': 90,
#  'does': 91,
#  'thing': 92,
#  'problem': 93,
#  'new': 94,
#  'much': 95,
#  'features': 96,
#  'any': 97,
#  'then': 98,
#  'programs': 99,
#  'power': 100,
#  'now': 101,
#  'service': 102,
#  'work': 103,
#  'buy': 104,
#  'works': 105,
#  'problems': 106,
#  'fast': 107,
#  'did': 108,
#  'toshiba': 109,
#  '7': 110,
#  'could': 111,
#  'size': 112,
#  'what': 113,
#  'am': 114,
#  'too': 115,
#  'working': 116,
#  'back': 117,
#  'your': 118,
#  ':': 119,
#  'speed': 120,
#  'machine': 121,
#  'best': 122,
#  'pro': 123,
#  'we': 124,
#  'were': 125,
#  'again': 126,
#  'pc': 127,
#  'performance': 128,
#  'little': 129,
#  'product': 130,
#  'many': 131,
#  '-': 132,
#  'really': 133,
#  'by': 134,
#  'need': 135,
#  'first': 136,
#  'having': 137,
#  "''": 138,
#  'some': 139,
#  'still': 140,
#  'months': 141,
#  'memory': 142,
#  'long': 143,
#  'been': 144,
#  'their': 145,
#  'bought': 146,
#  'better': 147,
#  'everything': 148,
#  'used': 149,
#  'warranty': 150,
#  'since': 151,
#  'worth': 152,
#  'graphics': 153,
#  'how': 154,
#  'design': 155,
#  'applications': 156,
#  'mouse': 157,
#  'comes': 158,
#  'run': 159,
#  'who': 160,
#  'every': 161,
#  'nice': 162,
#  'internet': 163,
#  'laptops': 164,
#  'never': 165,
#  'replaced': 166,
#  '3': 167,
#  'support': 168,
#  'games': 169,
#  'bad': 170,
#  'same': 171,
#  'right': 172,
#  '``': 173,
#  'runs': 174,
#  'looking': 175,
#  'enough': 176,
#  'using': 177,
#  'way': 178,
#  'running': 179,
#  'able': 180,
#  'program': 181,
#  'always': 182,
#  'lot': 183,
#  'dell': 184,
#  'another': 185,
#  "'ve": 186,
#  'pad': 187,
#  'netbook': 188,
#  'got': 189,
#  'operating': 190,
#  'hp': 191,
#  'money': 192,
#  'most': 193,
#  'went': 194,
#  'such': 195,
#  '$': 196,
#  'card': 197,
#  'them': 198,
#  'come': 199,
#  'large': 200,
#  'make': 201,
#  'gaming': 202,
#  'take': 203,
#  'hours': 204,
#  'look': 205,
#  'web': 206,
#  'over': 207,
#  'less': 208,
#  'ca': 209,
#  'around': 210,
#  'though': 211,
#  'excellent': 212,
#  'display': 213,
#  'made': 214,
#  '?': 215,
#  'awesome': 216,
#  'while': 217,
#  'issue': 218,
#  "'m": 219,
#  'makes': 220,
#  'next': 221,
#  'keep': 222,
#  'slow': 223,
#  'amazing': 224,
#  'month': 225,
#  'ever': 226,
#  'purchase': 227,
#  'perfect': 228,
#  'vista': 229,
#  'customer': 230,
#  'want': 231,
#  'carry': 232,
#  'feel': 233,
#  'bit': 234,
#  'small': 235,
#  'os': 236,
#  'easily': 237,
#  'should': 238,
#  'video': 239,
#  'overall': 240,
#  'two': 241,
#  'cheap': 242,
#  'off': 243,
#  'light': 244,
#  'find': 245,
#  'open': 246,
#  'called': 247,
#  'fix': 248,
#  'stopped': 249,
#  'go': 250,
#  'things': 251,
#  '5': 252,
#  'key': 253,
#  'pay': 254,
#  ';': 255,
#  'desktop': 256,
#  'cost': 257,
#  'fixed': 258,
#  'processor': 259,
#  'wonderful': 260,
#  'once': 261,
#  'sound': 262,
#  'pretty': 263,
#  'space': 264,
#  '2': 265,
#  'down': 266,
#  'high': 267,
#  'day': 268,
#  'external': 269,
#  'fan': 270,
#  'started': 271,
#  'quickly': 272,
#  'ease': 273,
#  '--': 274,
#  'word': 275,
#  'office': 276,
#  'without': 277,
#  'old': 278,
#  'computers': 279,
#  'came': 280,
#  'due': 281,
#  'lightweight': 282,
#  'cd': 283,
#  'see': 284,
#  'short': 285,
#  'say': 286,
#  'week': 287,
#  'repair': 288,
#  'ram': 289,
#  'charge': 290,
#  'boot': 291,
#  'completely': 292,
#  'warrenty': 293,
#  'took': 294,
#  'shipping': 295,
#  'microsoft': 296,
#  'doing': 297,
#  'set': 298,
#  'free': 299,
#  'virus': 300,
#  'keys': 301,
#  'supply': 302,
#  'feature': 303,
#  'send': 304,
#  'through': 305,
#  'know': 306,
#  'notebook': 307,
#  'being': 308,
#  'recommend': 309,
#  'trackpad': 310,
#  'compared': 311,
#  'think': 312,
#  'full': 313,
#  'anyone': 314,
#  'dvd': 315,
#  'faster': 316,
#  'change': 317,
#  'plus': 318,
#  'last': 319,
#  'something': 320,
#  'home': 321,
#  'company': 322,
#  'where': 323,
#  'before': 324,
#  'value': 325,
#  'built': 326,
#  'may': 327,
#  'however': 328,
#  "'re": 329,
#  'usb': 330,
#  'brand': 331,
#  'past': 332,
#  'motherboard': 333,
#  'charger': 334,
#  'hardware': 335,
#  'simple': 336,
#  'within': 337,
#  'touch': 338,
#  'yet': 339,
#  'acer': 340,
#  'yes': 341,
#  'few': 342,
#  'webcam': 343,
#  'play': 344,
#  "'d": 345,
#  'issues': 346,
#  'clear': 347,
#  'year': 348,
#  'thought': 349,
#  'far': 350,
#  'user': 351,
#  'itself': 352,
#  '1': 353,
#  'although': 354,
#  'these': 355,
#  'easier': 356,
#  'extra': 357,
#  'port': 358,
#  'getting': 359,
#  'etc': 360,
#  'must': 361,
#  'speakers': 362,
#  'looks': 363,
#  'iphoto': 364,
#  'worked': 365,
#  'found': 366,
#  'big': 367,
#  'learn': 368,
#  'seems': 369,
#  'center': 370,
#  'lots': 371,
#  'frustrating': 372,
#  'help': 373,
#  'fact': 374,
#  'upgraded': 375,
#  'pcs': 376,
#  'connect': 377,
#  'board': 378,
#  'making': 379,
#  'products': 380,
#  'needs': 381,
#  'cool': 382,
#  'until': 383,
#  'course': 384,
#  'resolution': 385,
#  'itunes': 386,
#  '13': 387,
#  'longer': 388,
#  'type': 389,
#  'store': 390,
#  'sent': 391,
#  'quick': 392,
#  'second': 393,
#  'processing': 394,
#  'poor': 395,
#  'expected': 396,
#  'years': 397,
#  'simply': 398,
#  'starter': 399,
#  'buttons': 400,
#  'build': 401,
#  'call': 402,
#  'others': 403,
#  'wireless': 404,
#  'plenty': 405,
#  'he': 406,
#  'actually': 407,
#  'failed': 408,
#  'someone': 409,
#  'cord': 410,
#  'extremely': 411,
#  'absolutely': 412,
#  'start': 413,
#  'dark': 414,
#  'multi-touch': 415,
#  'installed': 416,
#  'crashed': 417,
#  'added': 418,
#  'hd': 419,
#  'monitor': 420,
#  'several': 421,
#  'loud': 422,
#  'times': 423,
#  '4': 424,
#  'wanted': 425,
#  'constantly': 426,
#  'systems': 427,
#  'touchpad': 428,
#  'editing': 429,
#  'phone': 430,
#  'hour': 431,
#  'browsing': 432,
#  'playing': 433,
#  'replace': 434,
#  'believe': 435,
#  'xp': 436,
#  'wo': 437,
#  'online': 438,
#  'garageband': 439,
#  'bright': 440,
#  'navigate': 441,
#  'ilife': 442,
#  'sleek': 443,
#  'least': 444,
#  'premium': 445,
#  'box': 446,
#  'away': 447,
#  'anything': 448,
#  'worry': 449,
#  'sure': 450,
#  'book': 451,
#  'experience': 452,
#  'told': 453,
#  'portable': 454,
#  'needed': 455,
#  'going': 456,
#  'sony': 457,
#  'macbooks': 458,
#  'done': 459,
#  'useful': 460,
#  'horrible': 461,
#  '/': 462,
#  'weight': 463,
#  'movies': 464,
#  'led': 465,
#  'tried': 466,
#  'business': 467,
#  'background': 468,
#  'camera': 469,
#  'fine': 470,
#  'huge': 471,
#  'weeks': 472,
#  'deal': 473,
#  'superior': 474,
#  'upgrade': 475,
#  'media': 476,
#  'macs': 477,
#  'convenient': 478,
#  'real': 479,
#  'already': 480,
#  'worse': 481,
#  'specs': 482,
#  'disk': 483,
#  'front': 484,
#  'coming': 485,
#  'connection': 486,
#  'highly': 487,
#  'offers': 488,
#  'finally': 489,
#  'seemed': 490,
#  'disc': 491,
#  'enjoy': 492,
#  'extended': 493,
#  'knew': 494,
#  'trouble': 495,
#  'order': 496,
#  'documents': 497,
#  'crashing': 498,
#  'designed': 499,
#  'oh': 500,
#  'expensive': 501,
#  'top': 502,
#  "'ll": 503,
#  'charged': 504,
#  'sales': 505,
#  'average': 506,
#  'maybe': 507,
#  'gets': 508,
#  'wish': 509,
#  'might': 510,
#  'backlit': 511,
#  'volume': 512,
#  'install': 513,
#  'impressed': 514,
#  'including': 515,
#  'built-in': 516,
#  'hooked': 517,
#  'drop': 518,
#  'guess': 519,
#  'tax': 520,
#  'buying': 521,
#  'iwork': 522,
#  'our': 523,
#  'especially': 524,
#  'replacement': 525,
#  'shows': 526,
#  'x': 527,
#  'older': 528,
#  'ports': 529,
#  'intel': 530,
#  'version': 531,
#  'email': 532,
#  'hot': 533,
#  'cheaper': 534,
#  'takes': 535,
#  'load': 536,
#  'storage': 537,
#  'tech': 538,
#  'users': 539,
#  'fairly': 540,
#  'reason': 541,
#  'end': 542,
#  'operation': 543,
#  'sharp': 544,
#  'nearly': 545,
#  'flawlessly': 546,
#  'higher': 547,
#  'music': 548,
#  'included': 549,
#  'expense': 550,
#  'osx': 551,
#  'functions': 552,
#  'tv': 553,
#  'interface': 554,
#  'pleased': 555,
#  'professional': 556,
#  'care': 557,
#  'apps': 558,
#  'watching': 559,
#  'else': 560,
#  'beautiful': 561,
#  'inch': 562,
#  'inside': 563,
#  'trial': 564,
#  'own': 565,
#  'noticed': 566,
#  'left': 567,
#  'model': 568,
#  'case': 569,
#  'happy': 570,
#  'into': 571,
#  'definitely': 572,
#  'matter': 573,
#  'different': 574,
#  'button': 575,
#  'opened': 576,
#  'sized': 577,
#  'typing': 578,
#  'days': 579,
#  'froze': 580,
#  'adding': 581,
#  'loose': 582,
#  'number': 583,
#  'photos': 584,
#  'solid': 585,
#  'edges': 586,
#  'geek': 587,
#  'college': 588,
#  'both': 589,
#  'pictures': 590,
#  'half': 591,
#  'network': 592,
#  'nothing': 593,
#  'services': 594,
#  'said': 595,
#  'darker': 596,
#  'standard': 597,
#  'pages': 598,
#  '...': 599,
#  'strong': 600,
#  'purchased': 601,
#  'save': 602,
#  'almost': 603,
#  'apparently': 604,
#  'videos': 605,
#  'difference': 606,
#  'fit': 607,
#  'night': 608,
#  'usually': 609,
#  'entire': 610,
#  'stay': 611,
#  'properly': 612,
#  'plugged': 613,
#  'iphone': 614,
#  'talk': 615,
#  'crashes': 616,
#  'paying': 617,
#  'newer': 618,
#  'country': 619,
#  'certain': 620,
#  'drivers': 621,
#  'files': 622,
#  'slick': 623,
#  'died': 624,
#  'trying': 625,
#  'allows': 626,
#  'refused': 627,
#  'ipod': 628,
#  'mother': 629,
#  'yeah': 630,
#  'bar': 631,
#  'recovery': 632,
#  'available': 633,
#  'useless': 634,
#  'protection': 635,
#  'paid': 636,
#  'none': 637,
#  'reliable': 638,
#  'people': 639,
#  'chose': 640,
#  'spend': 641,
#  'mention': 642,
#  'slowly': 643,
#  'hold': 644,
#  'minutes': 645,
#  'stars': 646,
#  '+': 647,
#  'drawback': 648,
#  'break': 649,
#  'responsive': 650,
#  'amount': 651,
#  'terrific': 652,
#  'mic': 653,
#  'thru': 654,
#  'cam': 655,
#  'mostly': 656,
#  'imovie': 657,
#  'colors': 658,
#  'crisp': 659,
#  'leopard': 660,
#  'above': 661,
#  'core': 662,
#  'becomes': 663,
#  'body': 664,
#  'low': 665,
#  'im': 666,
#  'whole': 667,
#  '175': 668,
#  'side': 669,
#  'cooling': 670,
#  'viruses': 671,
#  '8': 672,
#  'keeps': 673,
#  'friendly': 674,
#  'caused': 675,
#  'remove': 676,
#  'smooth': 677,
#  'quite': 678,
#  'soon': 679,
#  'machines': 680,
#  'components': 681,
#  'lasting': 682,
#  'smoothly': 683,
#  'loaded': 684,
#  'via': 685,
#  'pack': 686,
#  'liked': 687,
#  'ahead': 688,
#  'hated': 689,
#  'quiet': 690,
#  'thats': 691,
#  'three': 692,
#  'necessary': 693,
#  'hook': 694,
#  'satellite': 695,
#  'boots': 696,
#  'die': 697,
#  'received': 698,
#  'priced': 699,
#  'burn': 700,
#  'probably': 701,
#  'why': 702,
#  'lose': 703,
#  '%': 704,
#  'unlike': 705,
#  '17': 706,
#  'offer': 707,
#  'updates': 708,
#  'versions': 709,
#  'special': 710,
#  'broke': 711,
#  'black': 712,
#  'seen': 713,
#  'world': 714,
#  'awful': 715,
#  'comfortable': 716,
#  'yourself': 717,
#  'doesnt': 718,
#  'during': 719,
#  'line': 720,
#  'clean': 721,
#  'discover': 722,
#  'looked': 723,
#  'rma': 724,
#  'contacted': 725,
#  'ups': 726,
#  'durable': 727,
#  'broken': 728,
#  'gb': 729,
#  'reasonable': 730,
#  'noise': 731,
#  'constant': 732,
#  'ghz': 733,
#  '500gb': 734,
#  'instead': 735,
#  'access': 736,
#  'rest': 737,
#  'wheel': 738,
#  'school': 739,
#  'programming': 740,
#  'worst': 741,
#  'blue': 742,
#  'larger': 743,
#  'gives': 744,
#  'relatively': 745,
#  'tutorials': 746,
#  'disappointing': 747,
#  'plug': 748,
#  'capabilities': 749,
#  'point': 750,
#  'seem': 751,
#  'downfall': 752,
#  'purchasing': 753,
#  'except': 754,
#  'plastic': 755,
#  'returned': 756,
#  'speaker': 757,
#  'student': 758,
#  'portability': 759,
#  'five': 760,
#  'person': 761,
#  'stuff': 762,
#  'turns': 763,
#  'often': 764,
#  'device': 765,
#  'fun': 766,
#  'plan': 767,
#  'previous': 768,
#  'operate': 769,
#  'unable': 770,
#  'track': 771,
#  'squad': 772,
#  'known': 773,
#  'either': 774,
#  'ask': 775,
#  'give': 776,
#  'expired': 777,
#  'fits': 778,
#  'budget': 779,
#  'besides': 780,
#  'slightly': 781,
#  'computing': 782,
#  'room': 783,
#  'bios': 784,
#  'benefits': 785,
#  'spoke': 786,
#  'she': 787,
#  'fantastic': 788,
#  'decent': 789,
#  'shipped': 790,
#  'general': 791,
#  'claim': 792,
#  'twice': 793,
#  'handle': 794,
#  'numbers': 795,
#  'sensitive': 796,
#  'cords': 797,
#  'taking': 798,
#  'gui': 799,
#  'bundled': 800,
#  'gorgeous': 801,
#  'turned': 802,
#  'freaking': 803,
#  'turn': 804,
#  'steady': 805,
#  'unnecessary': 806,
#  'unless': 807,
#  'suite': 808,
#  'satisfied': 809,
#  'barely': 810,
#  'connected': 811,
#  'pure': 812,
#  'snap': 813,
#  '30': 814,
#  'helps': 815,
#  'occasionally': 816,
#  'hundred': 817,
#  'dollars': 818,
#  'preloaded': 819,
#  'along': 820,
#  'realized': 821,
#  'kinda': 822,
#  'speaking': 823,
#  'browser': 824,
#  'under': 825,
#  'ago': 826,
#  'forced': 827,
#  'website': 828,
#  'force': 829,
#  'four': 830,
#  'advantage': 831,
#  'increase': 832,
#  'heated': 833,
#  'opening': 834,
#  'poorly': 835,
#  'intuitive': 836,
#  'download': 837,
#  'glass': 838,
#  'continued': 839,
#  'simpler': 840,
#  'forward': 841,
#  'genius': 842,
#  '10': 843,
#  'movie': 844,
#  'bluetooth': 845,
#  'customers': 846,
#  'white': 847,
#  'updated': 848,
#  'color': 849,
#  'comparison': 850,
#  'factor': 851,
#  'familiar': 852,
#  'couple': 853,
#  'complaints': 854,
#  'construction': 855,
#  'security': 856,
#  'stuck': 857,
#  'didnt': 858,
#  'dont': 859,
#  'safari': 860,
#  'delivery': 861,
#  'anytime': 862,
#  'mind': 863,
#  'ordered': 864,
#  'saved': 865,
#  'crystal': 866,
#  'owning': 867,
#  'become': 868,
#  'incredibly': 869,
#  'powerbook': 870,
#  'easiest': 871,
#  'surface': 872,
#  'snow': 873,
#  'learning': 874,
#  'picked': 875,
#  'check': 876,
#  'missing': 877,
#  'dual': 878,
#  'charging': 879,
#  'stand': 880,
#  'appleworks': 881,
#  'paint': 882,
#  'early': 883,
#  'edition': 884,
#  'report': 885,
#  'cheaply': 886,
#  'holds': 887,
#  'antivirus': 888,
#  'glad': 889,
#  'nicely': 890,
#  'part': 891,
#  'latest': 892,
#  'waited': 893,
#  'chat': 894,
#  'us': 895,
#  'wasted': 896,
#  'provides': 897,
#  'those': 898,
#  'unreliable': 899,
#  'meets': 900,
#  'spec': 901,
#  'burner': 902,
#  'discovered': 903,
#  'ran': 904,
#  'between': 905,
#  '1/2': 906,
#  'edge': 907,
#  'phones': 908,
#  'terrible': 909,
#  'hate': 910,
#  'opinion': 911,
#  'gave': 912,
#  'daughter': 913,
#  'listen': 914,
#  'major': 915,
#  'heavy': 916,
#  'bulky': 917,
#  'electronic': 918,
#  "'": 919,
#  'linux': 920,
#  'based': 921,
#  'sense': 922,
#  'rather': 923,
#  'processors': 924,
#  'hdmi': 925,
#  'firewire': 926,
#  'image': 927,
#  'kind': 928,
#  'clicking': 929,
#  'unsteady': 930,
#  'bugs': 931,
#  'junk': 932,
#  'facebook': 933,
#  'file': 934,
#  'particular': 935,
#  'truly': 936,
#  'bucks': 937,
#  'beyond': 938,
#  'duty': 939,
#  'crash': 940,
#  'decides': 941,
#  'mode': 942,
#  'dropping': 943,
#  'stock': 944,
#  'given': 945,
#  'graphic': 946,
#  'decreased': 947,
#  'thrilled': 948,
#  'technical': 949,
#  'skype': 950,
#  'hdd': 951,
#  'main': 952,
#  'understand': 953,
#  'consider': 954,
#  'ms': 955,
#  'amazed': 956,
#  'fully': 957,
#  'letters': 958,
#  'complete': 959,
#  'ergonomic': 960,
#  'sometimes': 961,
#  'notebooks': 962,
#  'quicker': 963,
#  'photography': 964,
#  '10-11': 965,
#  'depending': 966,
#  'level': 967,
#  'appearance': 968,
#  '3rd': 969,
#  'bother': 970,
#  'data': 971,
#  'taught': 972,
#  'photoshop': 973,
#  'bigger': 974,
#  'loves': 975,
#  'husband': 976,
#  'signals': 977,
#  'multiple': 978,
#  'page': 979,
#  'non': 980,
#  'frequently': 981,
#  'ideal': 982,
#  'improvements': 983,
#  'images': 984,
#  'later': 985,
#  'options': 986,
#  'girlfriend': 987,
#  'hinge': 988,
#  'lcd': 989,
#  'late': 990,
#  'issued': 991,
#  'morning': 992,
#  '60': 993,
#  'hiccups': 994,
#  'occasion': 995,
#  'presentations': 996,
#  'functioning': 997,
#  'obviously': 998,
#  'hinges': 999,
#  'advertised': 1000,
#  ...}

# %% [markdown]
# Fetching weights from pre trained Glove model (ATE)

# %%
for word, index in mapping_ate_glove.items():
    if word in glove:
        weights_ate_glove[index:] = glove[word]

# %% [markdown]
# Initializing the rnn Model using Glove embeddings

# %%
rnn_model_glove = Sequential()
rnn_model_glove.add(Embedding(input_dim = vocab_size_ate,output_dim = 300,input_length  = 100,weights = [weights_ate_glove],trainable = False))
rnn_model_glove.add(SimpleRNN(64, return_sequences=True))
rnn_model_glove.add(TimeDistributed(Dense(Y_padded_train.shape[2], activation='softmax')))
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Compiling the rnn Glove Model

# %%
rnn_model_glove.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['acc',Precision(),Recall()])
# Out:
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
rnn_f1_callback_val = F1ScoreCallback(data=(X_padded_val, Y_padded_val),name='validation')
rnn_f1_callback_train=F1ScoreCallback(data=(X_padded_train, Y_padded_train),name='training')

# %%
rnn_model_glove.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 300)          721800
#
#  simple_rnn (SimpleRNN)      (None, 100, 64)           23360
#
#  time_distributed (TimeDist  (None, 100, 4)            260
#  ributed)
#
# =================================================================
# Total params: 745420 (2.84 MB)
# Trainable params: 23620 (92.27 KB)
# Non-trainable params: 721800 (2.75 MB)
# _________________________________________________________________

# %% [markdown]
# Fitting the rnn model

# %%
rnn_training_glove = rnn_model_glove.fit(X_padded_train, Y_padded_train, batch_size=128, epochs=15, validation_data=(X_padded_val, Y_padded_val), callbacks=[rnn_f1_callback_train,rnn_f1_callback_val])
# Out:
# Epoch 1/15
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Python311\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 29/29 [==============================] - 0s 8ms/steps: 1.1351 - acc: 0.8224 - precision: 0.7838 - reca
# training F1 Score: 0.48590153093815447
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.4771687733181673
# 8/8 [==============================] - 5s 450ms/step - loss: 1.1351 - acc: 0.8224 - precision: 0.7838 - recall: 0.0796 - val_loss: 0.6490 - val_acc: 0.9600 - val_precision: 0.9670 - val_recall: 0.7786
# Epoch 2/15
# 29/29 [==============================] - 0s 9ms/steps: 0.4438 - acc: 0.9677 - precision: 0.9738 - reca
# training F1 Score: 0.47138465783386996
# 7/7 [==============================] - 0s 9ms/step
# validation F1 Score: 0.45669879995332796
# 8/8 [==============================] - 3s 440ms/step - loss: 0.4422 - acc: 0.9675 - precision: 0.9736 - recall: 0.8515 - val_loss: 0.2937 - val_acc: 0.9454 - val_precision: 0.9471 - val_recall: 0.8821
# Epoch 3/15
# 29/29 [==============================] - 0s 8ms/steps: 0.2112 - acc: 0.9636 - precision: 0.9644 - reca
# training F1 Score: 0.4787580966028512
# 7/7 [==============================] - 0s 7ms/step
# validation F1 Score: 0.4764878910180941
# 8/8 [==============================] - 3s 385ms/step - loss: 0.2106 - acc: 0.9638 - precision: 0.9645 - recall: 0.9107 - val_loss: 0.1903 - val_acc: 0.9561 - val_precision: 0.9593 - val_recall: 0.9130
# Epoch 4/15
# 29/29 [==============================] - 0s 8ms/steps: 0.1486 - acc: 0.9697 - precision: 0.9705 - reca
# training F1 Score: 0.5065150375318118
# 7/7 [==============================] - 0s 7ms/step
# validation F1 Score: 0.5096986795070968
# 8/8 [==============================] - 2s 341ms/step - loss: 0.1486 - acc: 0.9696 - precision: 0.9705 - recall: 0.9285 - val_loss: 0.1568 - val_acc: 0.9627 - val_precision: 0.9666 - val_recall: 0.9196
# Epoch 5/15
# 29/29 [==============================] - 0s 9ms/steps: 0.1262 - acc: 0.9749 - precision: 0.9763 - reca
# training F1 Score: 0.5218943289408965
# 7/7 [==============================] - 0s 7ms/step
# validation F1 Score: 0.5198107163328978
# 8/8 [==============================] - 3s 353ms/step - loss: 0.1260 - acc: 0.9750 - precision: 0.9763 - recall: 0.9421 - val_loss: 0.1392 - val_acc: 0.9675 - val_precision: 0.9720 - val_recall: 0.9352
# Epoch 6/15
# 29/29 [==============================] - 0s 8ms/steps: 0.1126 - acc: 0.9778 - precision: 0.9788 - reca
# training F1 Score: 0.5355611192495697
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.5406716855129524
# 8/8 [==============================] - 2s 350ms/step - loss: 0.1125 - acc: 0.9778 - precision: 0.9788 - recall: 0.9466 - val_loss: 0.1289 - val_acc: 0.9697 - val_precision: 0.9740 - val_recall: 0.9373
# Epoch 7/15
# 29/29 [==============================] - 0s 9ms/steps: 0.1040 - acc: 0.9793 - precision: 0.9803 - reca
# training F1 Score: 0.560486799876228
# 7/7 [==============================] - 0s 7ms/step
# validation F1 Score: 0.5587720268343227
# 8/8 [==============================] - 3s 368ms/step - loss: 0.1041 - acc: 0.9793 - precision: 0.9803 - recall: 0.9481 - val_loss: 0.1224 - val_acc: 0.9706 - val_precision: 0.9747 - val_recall: 0.9381
# Epoch 8/15
# 29/29 [==============================] - 0s 10ms/step: 0.0978 - acc: 0.9804 - precision: 0.9818 - reca
# training F1 Score: 0.5889579535849119
# 7/7 [==============================] - 0s 7ms/step
# validation F1 Score: 0.580373533440528
# 8/8 [==============================] - 3s 358ms/step - loss: 0.0977 - acc: 0.9804 - precision: 0.9818 - recall: 0.9487 - val_loss: 0.1175 - val_acc: 0.9716 - val_precision: 0.9763 - val_recall: 0.9389
# Epoch 9/15
# 29/29 [==============================] - 0s 10ms/step: 0.0927 - acc: 0.9811 - precision: 0.9829 - re
# training F1 Score: 0.6139934717823134
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.5993774510504062
# 8/8 [==============================] - 3s 371ms/step - loss: 0.0926 - acc: 0.9811 - precision: 0.9829 - recall: 0.9491 - val_loss: 0.1139 - val_acc: 0.9723 - val_precision: 0.9778 - val_recall: 0.9492
# Epoch 10/15
# 29/29 [==============================] - 0s 8ms/steps: 0.0883 - acc: 0.9816 - precision: 0.9834 - reca
# training F1 Score: 0.6205878436629333
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.6031662168188447
# 8/8 [==============================] - 3s 366ms/step - loss: 0.0883 - acc: 0.9816 - precision: 0.9834 - recall: 0.9595 - val_loss: 0.1110 - val_acc: 0.9732 - val_precision: 0.9777 - val_recall: 0.9496
# Epoch 11/15
# 29/29 [==============================] - 0s 8ms/steps: 0.0845 - acc: 0.9820 - precision: 0.9839 - reca
# training F1 Score: 0.6451037030269322
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.6216147212095997
# 8/8 [==============================] - 3s 357ms/step - loss: 0.0846 - acc: 0.9820 - precision: 0.9839 - recall: 0.9600 - val_loss: 0.1087 - val_acc: 0.9735 - val_precision: 0.9785 - val_recall: 0.9497
# Epoch 12/15
# 29/29 [==============================] - 0s 8ms/steps: 0.0811 - acc: 0.9826 - precision: 0.9848 - reca
# training F1 Score: 0.6691532717487805
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.6432044343872417
# 8/8 [==============================] - 2s 342ms/step - loss: 0.0811 - acc: 0.9826 - precision: 0.9848 - recall: 0.9605 - val_loss: 0.1068 - val_acc: 0.9739 - val_precision: 0.9785 - val_recall: 0.9498
# Epoch 13/15
# 29/29 [==============================] - 0s 8ms/steps: 0.0781 - acc: 0.9831 - precision: 0.9855 - reca
# training F1 Score: 0.6810324242765723
# 7/7 [==============================] - 0s 7ms/step
# validation F1 Score: 0.6541497503324178
# 8/8 [==============================] - 3s 356ms/step - loss: 0.0781 - acc: 0.9831 - precision: 0.9855 - recall: 0.9608 - val_loss: 0.1053 - val_acc: 0.9740 - val_precision: 0.9791 - val_recall: 0.9503
# Epoch 14/15
# 29/29 [==============================] - 0s 9ms/steps: 0.0753 - acc: 0.9836 - precision: 0.9861 - reca
# training F1 Score: 0.7041603612050332
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.6651007224151013
# 8/8 [==============================] - 3s 391ms/step - loss: 0.0754 - acc: 0.9836 - precision: 0.9861 - recall: 0.9613 - val_loss: 0.1038 - val_acc: 0.9743 - val_precision: 0.9793 - val_recall: 0.9504
# Epoch 15/15
# 29/29 [==============================] - 0s 9ms/steps: 0.0729 - acc: 0.9841 - precision: 0.9865 - reca
# training F1 Score: 0.7176261168990041
# 7/7 [==============================] - 0s 8ms/step
# validation F1 Score: 0.6819779773295027
# 8/8 [==============================] - 3s 360ms/step - loss: 0.0729 - acc: 0.9841 - precision: 0.9864 - recall: 0.9617 - val_loss: 0.1027 - val_acc: 0.9748 - val_precision: 0.9789 - val_recall: 0.9506

# %% [markdown]
# Testing accuracy

# %%
accuracy = rnn_model_glove.evaluate(X_padded_test, Y_padded_test, verbose = 1)
print(accuracy[1])
# Out:
#  8/11 [====================>.........] - ETA: 0s - loss: 0.1138 - acc: 0.9734 - precision: 0.9776 - recall: 0.9510
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1158 - acc: 0.9716 - precision: 0.9769 - recall: 0.9491
# 0.9716463685035706

# %% [markdown]
# Testing F1 Score

# %%
Y_pred_ate = rnn_model_glove.predict(X_padded_test)
real = get_real(Y_padded_test)
pred = get_pred(Y_pred_ate)

true_labels_flat = [label for sublist in real for label in sublist]
predicted_labels_flat = [label for sublist in pred for label in sublist]

# Compute F1 score
f1 = f1_score(true_labels_flat, predicted_labels_flat, average='macro')

print("F1 Score:", f1)
# Out:
#  7/11 [==================>...........] - ETA: 0s
# 11/11 [==============================] - 0s 8ms/step
# F1 Score: 0.6545637746114141

# %% [markdown]
# Plotting the graph

# %%
draw_loss_graph(rnn_training_glove, "rnn Model", rnn_f1_callback_train.f1_scores, rnn_f1_callback_val.f1_scores)
save_model(rnn_model_glove, "rnn","Glove","t2","ATE")
loaded_model = load_model("Saved_Models/ATE/t2_rnn_Glove.pkl")
