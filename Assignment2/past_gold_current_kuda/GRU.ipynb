# %%
from IMPORTS import *

seed_value = 16
np.random.seed(seed_value)
tf.random.set_seed(seed_value)
# Out:
# WARNING:tensorflow:From c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.15.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# Reading ATE json files

# %%
ATE_train = None
ATE_test = None
ATE_val = None
with open("Task1\processed\ATE_train.json") as f1:
    ATE_train  = json.load(f1)

with open("Task1\processed\ATE_test.json") as f2:
    ATE_test = json.load(f2)

with open("Task1\processed\ATE_val.json") as f3:
    ATE_val = json.load(f3)

# %% [markdown]
# Reading NER json files

# %%
NER_train = None
NER_test = None
NER_val = None
with open("Task1\processed\\NER_train.json") as f1:
    NER_train  = json.load(f1)

with open("Task1\processed\\NER_test.json") as f2:
    NER_test = json.load(f2)

with open("Task1\processed\\NER_val.json") as f3:
    NER_val = json.load(f3)

# %% [markdown]
# Loading the pre-trained models (Word2Vec, GloVE and fasttext)

# %%
word2vec = KeyedVectors.load_word2vec_format('WordEmbeddings/Word2Vec.bin',binary=True)

# %% [markdown]
# ATE Dataset

# %%
X_train_ate,Y_train_ate= create_train_test_val(ATE_train)
X_test_ate,Y_test_ate = create_train_test_val(ATE_test)
X_val_ate,Y_val_ate = create_train_test_val(ATE_val)

# %% [markdown]
# NER Dataset

# %%
X_train_ner,Y_train_ner = create_train_test_val(NER_train)
X_test_ner,Y_test_ner = create_train_test_val(NER_test)
X_val_ner,Y_val_ner = create_train_test_val(NER_val)

# %% [markdown]
# Tokenizing the ATE Dataset

# %%
X_train_ate_tokenized, toke = TokenCreator(X_train_ate,1)
X_test_ate_tokenized = TokenCreator(X_test_ate,0,tokenizer = toke)
X_val_ate_tokenized = TokenCreator(X_val_ate,0,tokenizer = toke)

Y_train_ate_tokenized,toke2 = TokenCreator(Y_train_ate,0)
Y_test_ate_tokenized = TokenCreator(Y_test_ate,0,tokenizer = toke2)
Y_val_ate_tokenized = TokenCreator(Y_val_ate,0,tokenizer = toke2)

# %% [markdown]
# Tokenizing the NER Dataset

# %%
X_train_ner_tokenized, toke = TokenCreator(X_train_ner,1)
X_test_ner_tokenized = TokenCreator(X_test_ner,0,tokenizer = toke)
X_val_ner_tokenized = TokenCreator(X_val_ner,0,tokenizer = toke)

Y_train_ner_tokenized,toke2 = TokenCreator(Y_train_ner,0)
Y_test_ner_tokenized = TokenCreator(Y_test_ner,0,tokenizer = toke2)
Y_val_ner_tokenized = TokenCreator(Y_val_ner,0,tokenizer = toke2)

# %% [markdown]
# Vocabulary of ATE

# %%
st1 = find_vocab(X_train_ate_tokenized)
vocab_size_ate  = len(st1) + 1 
vocab_size_ate
# Out:
# 2406

# %% [markdown]
# Vocabulary of NER

# %%
st2 = find_vocab(X_train_ner_tokenized)
vocab_size_ner = len(st2) + 1
vocab_size_ner
# Out:
# 30220

# %% [markdown]
# Padding ATE

# %%
X_padded_train = pad_sequences(X_train_ate_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_train = pad_sequences(Y_train_ate_tokenized, maxlen=100, padding="pre", truncating="post")

X_padded_test = pad_sequences(X_test_ate_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_test = pad_sequences(Y_test_ate_tokenized, maxlen=100, padding="pre", truncating="post")

X_padded_val = pad_sequences(X_val_ate_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_val = pad_sequences(Y_val_ate_tokenized, maxlen=100, padding="pre", truncating="post")

# %% [markdown]
# Padding NER

# %%
X_padded_train_ner = pad_sequences(X_train_ner_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_train_ner = pad_sequences(Y_train_ner_tokenized, maxlen=100, padding="pre", truncating="post")

X_padded_test_ner = pad_sequences(X_test_ner_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_test_ner = pad_sequences(Y_test_ner_tokenized, maxlen=100, padding="pre", truncating="post")

X_padded_val_ner = pad_sequences(X_val_ner_tokenized, maxlen=100, padding="pre", truncating="post")
Y_padded_val_ner = pad_sequences(Y_val_ner_tokenized, maxlen=100, padding="pre", truncating="post")

# %% [markdown]
# One hot encoding the ATE labels

# %%
Y_padded_train = to_categorical(Y_padded_train)
Y_padded_test = to_categorical(Y_padded_test)
Y_padded_val = to_categorical(Y_padded_val)

# %% [markdown]
# One hot encoding the NER labels

# %%
Y_padded_train_ner = to_categorical(Y_padded_train_ner)
Y_padded_test_ner = to_categorical(Y_padded_test_ner)
Y_padded_val_ner = to_categorical(Y_padded_val_ner)

# %% [markdown]
# Assigning ATE Word2Vec mapping

# %%
weights_ate_word2vec = np.zeros((vocab_size_ate, 300))

mapping_ate_word2vec = toke.word_index 
mapping_ate_word2vec
# Out:
# {'#UK': 1,
#  'the': 2,
#  'of': 3,
#  'in': 4,
#  'to': 5,
#  'and': 6,
#  'that': 7,
#  'a': 8,
#  'was': 9,
#  'is': 10,
#  'by': 11,
#  'on': 12,
#  'as': 13,
#  'for': 14,
#  'be': 15,
#  'it': 16,
#  'court': 17,
#  'not': 18,
#  'has': 19,
#  'under': 20,
#  'this': 21,
#  'section': 22,
#  'which': 23,
#  'with': 24,
#  'or': 25,
#  'at': 26,
#  'he': 27,
#  'case': 28,
#  'no.': 29,
#  'from': 30,
#  'been': 31,
#  'his': 32,
#  'an': 33,
#  'had': 34,
#  'are': 35,
#  'were': 36,
#  'v.': 37,
#  'state': 38,
#  'also': 39,
#  'have': 40,
#  'act': 41,
#  'order': 42,
#  'any': 43,
#  'no': 44,
#  'high': 45,
#  'accused': 46,
#  'learned': 47,
#  'said': 48,
#  'there': 49,
#  'dated': 50,
#  'supreme': 51,
#  'made': 52,
#  'would': 53,
#  'before': 54,
#  'singh': 55,
#  'held': 56,
#  'who': 57,
#  'such': 58,
#  'against': 59,
#  'other': 60,
#  'but': 61,
#  'their': 62,
#  'one': 63,
#  'if': 64,
#  'respondent': 65,
#  'filed': 66,
#  'appeal': 67,
#  'appellant': 68,
#  'evidence': 69,
#  '&': 70,
#  'all': 71,
#  'only': 72,
#  'decision': 73,
#  'after': 74,
#  'we': 75,
#  'they': 76,
#  'petitioner': 77,
#  'government': 78,
#  'may': 79,
#  'judgment': 80,
#  'act,': 81,
#  'its': 82,
#  'when': 83,
#  'counsel': 84,
#  'view': 85,
#  'same': 86,
#  'application': 87,
#  'india': 88,
#  'out': 89,
#  'can': 90,
#  'further': 91,
#  'petition': 92,
#  'whether': 93,
#  'two': 94,
#  'bench': 95,
#  'stated': 96,
#  'provisions': 97,
#  'question': 98,
#  'her': 99,
#  'law': 100,
#  'cannot': 101,
#  'vs.': 102,
#  'therefore,': 103,
#  'civil': 104,
#  'first': 105,
#  'article': 106,
#  'police': 107,
#  'should': 108,
#  'mr.': 109,
#  '1': 110,
#  'suit': 111,
#  'could': 112,
#  'upon': 113,
#  'will': 114,
#  'these': 115,
#  'taken': 116,
#  'so': 117,
#  'passed': 118,
#  'writ': 119,
#  'rule': 120,
#  'about': 121,
#  'where': 122,
#  'referred': 123,
#  'judge': 124,
#  'being': 125,
#  'him': 126,
#  'given': 127,
#  'even': 128,
#  'i': 129,
#  'kumar': 130,
#  'into': 131,
#  'right': 132,
#  'p.': 133,
#  'present': 134,
#  'per': 135,
#  'ltd.': 136,
#  'rs.': 137,
#  'act.': 138,
#  '2': 139,
#  ':': 140,
#  'air': 141,
#  'time': 142,
#  'criminal': 143,
#  "hon'ble": 144,
#  'constitution': 145,
#  'j.': 146,
#  'delhi': 147,
#  'defendant': 148,
#  'issued': 149,
#  'matter': 150,
#  'shall': 151,
#  'must': 152,
#  'did': 153,
#  'plaintiff': 154,
#  'respect': 155,
#  'she': 156,
#  'statement': 157,
#  'submitted': 158,
#  'company': 159,
#  '3': 160,
#  'case,': 161,
#  'special': 162,
#  'property': 163,
#  's.': 164,
#  'then': 165,
#  'shri': 166,
#  'power': 167,
#  'between': 168,
#  'does': 169,
#  'while': 170,
#  'notice': 171,
#  'tribunal': 172,
#  'within': 173,
#  'above': 174,
#  'date': 175,
#  'trial': 176,
#  'person': 177,
#  'public': 178,
#  'facts': 179,
#  'offence': 180,
#  'sc': 181,
#  'scc': 182,
#  'court,': 183,
#  'having': 184,
#  'however,': 185,
#  'deceased': 186,
#  'tax': 187,
#  'division': 188,
#  'house': 189,
#  'land': 190,
#  'them': 191,
#  'petitioners': 192,
#  'district': 193,
#  'new': 194,
#  '(1)': 195,
#  'code': 196,
#  'apex': 197,
#  'relied': 198,
#  'general': 199,
#  'persons': 200,
#  'down': 201,
#  'officer': 202,
#  'observed': 203,
#  'found': 204,
#  'justice': 205,
#  'court.': 206,
#  'union': 207,
#  'both': 208,
#  '4': 209,
#  'examined': 210,
#  'central': 211,
#  'without': 212,
#  'what': 213,
#  'some': 214,
#  'reference': 215,
#  'though': 216,
#  'came': 217,
#  'sections': 218,
#  'indian': 219,
#  'cases': 220,
#  'another': 221,
#  'jurisdiction': 222,
#  'page': 223,
#  'basis': 224,
#  'claim': 225,
#  'amount': 226,
#  'report': 227,
#  'effect': 228,
#  'up': 229,
#  'part': 230,
#  'possession': 231,
#  'witness': 232,
#  'following': 233,
#  '5': 234,
#  '-': 235,
#  'assessee': 236,
#  'since': 237,
#  'year': 238,
#  'prosecution': 239,
#  'fact': 240,
#  'authority': 241,
#  'bank': 242,
#  'considered': 243,
#  'complainant': 244,
#  'during': 245,
#  'behalf': 246,
#  'three': 247,
#  '(2)': 248,
#  'service': 249,
#  'years': 250,
#  'income': 251,
#  'ram': 252,
#  'regard': 253,
#  '6': 254,
#  'c.': 255,
#  'rules': 256,
#  'placed': 257,
#  'sale': 258,
#  'co.': 259,
#  'reported': 260,
#  'proceedings': 261,
#  'place': 262,
#  'aforesaid': 263,
#  'record': 264,
#  'because': 265,
#  'appellants': 266,
#  'do': 267,
#  'complaint': 268,
#  'registered': 269,
#  'necessary': 270,
#  'additional': 271,
#  'make': 272,
#  'well': 273,
#  'according': 274,
#  'respondents': 275,
#  'ground': 276,
#  'chief': 277,
#  'period': 278,
#  'through': 279,
#  'procedure': 280,
#  'those': 281,
#  'business': 282,
#  'more': 283,
#  'clause': 284,
#  'relevant': 285,
#  '(supra)': 286,
#  'interest': 287,
#  'legal': 288,
#  'mentioned': 289,
#  'our': 290,
#  'favour': 291,
#  'take': 292,
#  'second': 293,
#  'read': 294,
#  'over': 295,
#  'far': 296,
#  'than': 297,
#  'others': 298,
#  'decided': 299,
#  'point': 300,
#  'witnesses': 301,
#  'set': 302,
#  'deposed': 303,
#  'singh,': 304,
#  'pw': 305,
#  'judicial': 306,
#  'ors.': 307,
#  'certain': 308,
#  'consideration': 309,
#  'now': 310,
#  'circumstances': 311,
#  'assessment': 312,
#  'issue': 313,
#  'laid': 314,
#  'terms': 315,
#  'letter': 316,
#  'p.w.': 317,
#  'support': 318,
#  'board': 319,
#  'received': 320,
#  'nos.': 321,
#  'account': 322,
#  'provision': 323,
#  'punjab': 324,
#  'earlier': 325,
#  'insurance': 326,
#  'ex.': 327,
#  'goods': 328,
#  'contention': 329,
#  'corporation': 330,
#  'notification': 331,
#  'commission': 332,
#  '7': 333,
#  'bombay': 334,
#  '8': 335,
#  'india,': 336,
#  'sessions': 337,
#  'took': 338,
#  'party': 339,
#  'r.': 340,
#  'vide': 341,
#  'purpose': 342,
#  'pradesh': 343,
#  'used': 344,
#  'already': 345,
#  'alleged': 346,
#  'recorded': 347,
#  'name': 348,
#  'compensation': 349,
#  'contended': 350,
#  'dr.': 351,
#  '"the': 352,
#  'parties': 353,
#  'clear': 354,
#  'commissioner': 355,
#  'show': 356,
#  'entitled': 357,
#  'us': 358,
#  'directed': 359,
#  'action': 360,
#  'courts': 361,
#  'different': 362,
#  'reliance': 363,
#  'no.1': 364,
#  'office': 365,
#  'admitted': 366,
#  'case.': 367,
#  'decisions': 368,
#  'agreement': 369,
#  'thus': 370,
#  'come': 371,
#  'due': 372,
#  'income-tax': 373,
#  'magistrate': 374,
#  'regarding': 375,
#  'transport': 376,
#  'w.': 377,
#  'granted': 378,
#  'decree': 379,
#  '10': 380,
#  'sri': 381,
#  'k.': 382,
#  'my': 383,
#  'ipc': 384,
#  'motor': 385,
#  'file': 386,
#  'required': 387,
#  'vehicle': 388,
#  'orders': 389,
#  'charge': 390,
#  'paid': 391,
#  'very': 392,
#  'and,': 393,
#  ',': 394,
#  'lal': 395,
#  'payment': 396,
#  'subject': 397,
#  'medical': 398,
#  'exercise': 399,
#  'allowed': 400,
#  'original': 401,
#  'impugned': 402,
#  'opinion': 403,
#  'pay': 404,
#  'investigation': 405,
#  'rights': 406,
#  '.': 407,
#  'powers': 408,
#  'smt.': 409,
#  'contract': 410,
#  'appellate': 411,
#  'observations': 412,
#  'meaning': 413,
#  'a.': 414,
#  'appears': 415,
#  'owner': 416,
#  '9': 417,
#  'way': 418,
#  'nature': 419,
#  '14': 420,
#  'grant': 421,
#  'j.,': 422,
#  'reasonable': 423,
#  'brought': 424,
#  '2.': 425,
#  'itself': 426,
#  'list': 427,
#  'duty': 428,
#  'death': 429,
#  'concerned': 430,
#  'taking': 431,
#  'available': 432,
#  'nor': 433,
#  'third': 434,
#  '12': 435,
#  'copy': 436,
#  'legislature': 437,
#  'therefore': 438,
#  'either': 439,
#  'single': 440,
#  'cr.p.c.': 441,
#  'raised': 442,
#  'again': 443,
#  'full': 444,
#  'find': 445,
#  'judge,': 446,
#  'prasad': 447,
#  'consider': 448,
#  'words': 449,
#  'along': 450,
#  'sh.': 451,
#  'provided': 452,
#  'claimed': 453,
#  'him.': 454,
#  'itr': 455,
#  'documents': 456,
#  'material': 457,
#  'area': 458,
#  'fir': 459,
#  'examination': 460,
#  'station': 461,
#  'each': 462,
#  'village': 463,
#  'clearly': 464,
#  'similar': 465,
#  'holding': 466,
#  'transfer': 467,
#  'pointed': 468,
#  'document': 469,
#  'offences': 470,
#  'penal': 471,
#  'm.': 472,
#  'post': 473,
#  'india.': 474,
#  'n.': 475,
#  'election': 476,
#  'including': 477,
#  '@': 478,
#  'liable': 479,
#  'sub-section': 480,
#  'written': 481,
#  'leave': 482,
#  'based': 483,
#  'information': 484,
#  'appeals': 485,
#  'own': 486,
#  'sent': 487,
#  'hold': 488,
#  'number': 489,
#  'reason': 490,
#  'industrial': 491,
#  'open': 492,
#  'sought': 493,
#  'course': 494,
#  'revenue': 495,
#  'force': 496,
#  'position': 497,
#  'liability': 498,
#  'back': 499,
#  'established': 500,
#  'para': 501,
#  'madras': 502,
#  'parliament': 503,
#  'cit': 504,
#  'true': 505,
#  'affidavit': 506,
#  'statutory': 507,
#  'considering': 508,
#  'entry': 509,
#  '1st': 510,
#  'common': 511,
#  'award': 512,
#  'constitution.': 513,
#  'dismissed': 514,
#  'dispute': 515,
#  'son': 516,
#  'articles': 517,
#  'applicable': 518,
#  'give': 519,
#  'petitions': 520,
#  'advocate': 521,
#  'went': 522,
#  'services': 523,
#  'proved': 524,
#  'cause': 525,
#  'produced': 526,
#  '1,': 527,
#  'defendants': 528,
#  'principles': 529,
#  'kerala': 530,
#  'various': 531,
#  'reasons': 532,
#  'punishable': 533,
#  'merely': 534,
#  'that,': 535,
#  'wife': 536,
#  'result': 537,
#  'working': 538,
#  'b.': 539,
#  'rajasthan': 540,
#  'm/s': 541,
#  'body': 542,
#  'contained': 543,
#  'prior': 544,
#  'scheme': 545,
#  'appearing': 546,
#  '15': 547,
#  'vehicles': 548,
#  'father': 549,
#  '11': 550,
#  'loss': 551,
#  'making': 552,
#  'ld.': 553,
#  'limited': 554,
#  '(3)': 555,
#  'put': 556,
#  '(b)': 557,
#  'conclusion': 558,
#  'concerned,': 559,
#  'member': 560,
#  'use': 561,
#  'amendment': 562,
#  'officer,': 563,
#  'wherein': 564,
#  'registration': 565,
#  'himself': 566,
#  'bearing': 567,
#  'haryana': 568,
#  'relating': 569,
#  'sufficient': 570,
#  'argued': 571,
#  'law.': 572,
#  'recovery': 573,
#  'accepted': 574,
#  'control': 575,
#  'trade': 576,
#  'premises': 577,
#  'left': 578,
#  'crime': 579,
#  'senior': 580,
#  'thus,': 581,
#  'injuries': 582,
#  'family': 583,
#  'committed': 584,
#  'principle': 585,
#  'done': 586,
#  'nothing': 587,
#  'form': 588,
#  'department': 589,
#  '4.': 590,
#  'rent': 591,
#  'ltd.,': 592,
#  '1.': 593,
#  '34': 594,
#  'head': 595,
#  'noted': 596,
#  '(air': 597,
#  'construction': 598,
#  'preferred': 599,
#  'certificate': 600,
#  'committee': 601,
#  'finding': 602,
#  'like': 603,
#  'private': 604,
#  'entered': 605,
#  'chand': 606,
#  'provides': 607,
#  'got': 608,
#  'sum': 609,
#  'particular': 610,
#  'proceeding': 611,
#  'argument': 612,
#  'last': 613,
#  'lord': 614,
#  'national': 615,
#  'settled': 616,
#  'valid': 617,
#  'assistant': 618,
#  'cheque': 619,
#  'members': 620,
#  'treated': 621,
#  'word': 622,
#  'light': 623,
#  '226': 624,
#  '(a)': 625,
#  '"': 626,
#  'towards': 627,
#  'statute': 628,
#  'obtained': 629,
#  'applicant': 630,
#  'magistrate,': 631,
#  'age': 632,
#  'm/s.': 633,
#  'council': 634,
#  'heard': 635,
#  'value': 636,
#  'connection': 637,
#  'appointed': 638,
#  'inspector': 639,
#  'denied': 640,
#  'outside': 641,
#  'drawn': 642,
#  'stage': 643,
#  'note': 644,
#  'follows:': 645,
#  'calcutta': 646,
#  'brother': 647,
#  'every': 648,
#  'see': 649,
#  'intention': 650,
#  'defence': 651,
#  'karnataka': 652,
#  'thereafter': 653,
#  'stand': 654,
#  'u/s': 655,
#  'near': 656,
#  'accident': 657,
#  'deed': 658,
#  'prove': 659,
#  'deputy': 660,
#  'followed': 661,
#  '13': 662,
#  'context': 663,
#  'i.e.': 664,
#  'guilty': 665,
#  'called': 666,
#  'proviso': 667,
#  'lordships': 668,
#  'revision': 669,
#  'doubt': 670,
#  'sentence': 671,
#  'states': 672,
#  'mind': 673,
#  'appointment': 674,
#  'judges': 675,
#  'policy': 676,
#  'accused.': 677,
#  'road': 678,
#  'hearing': 679,
#  'tamil': 680,
#  'dealing': 681,
#  'go': 682,
#  'scope': 683,
#  'bail': 684,
#  'conditions': 685,
#  'proper': 686,
#  '20': 687,
#  'west': 688,
#  'seeking': 689,
#  '(c)': 690,
#  'filing': 691,
#  'them.': 692,
#  'relief': 693,
#  'legislative': 694,
#  'sales': 695,
#  'accordance': 696,
#  'so,': 697,
#  'etc.': 698,
#  'till': 699,
#  'need': 700,
#  'andhra': 701,
#  'aside': 702,
#  'code.': 703,
#  'competent': 704,
#  'fundamental': 705,
#  'day': 706,
#  'specific': 707,
#  '16': 708,
#  'prepared': 709,
#  'under:': 710,
#  'authorities': 711,
#  'madhya': 712,
#  'executed': 713,
#  'hospital': 714,
#  'refer': 715,
#  'purposes': 716,
#  'decide': 717,
#  'raj': 718,
#  'matters': 719,
#  'seen': 720,
#  'sharma': 721,
#  'gujarat': 722,
#  'rules,': 723,
#  'ipc.': 724,
#  'excise': 725,
#  '3.': 726,
#  'reached': 727,
#  'contrary': 728,
#  'rendered': 729,
#  'schedule': 730,
#  'firm': 731,
#  'devi': 732,
#  'limitation': 733,
#  'conviction': 734,
#  'covered': 735,
#  'validity': 736,
#  'acquisition': 737,
#  'chandra': 738,
#  'paragraph': 739,
#  'days': 740,
#  'work': 741,
#  'bihar': 742,
#  'thereafter,': 743,
#  'failed': 744,
#  'get': 745,
#  'appropriate': 746,
#  'review': 747,
#  'direction': 748,
#  'subsequent': 749,
#  'director': 750,
#  'namely': 751,
#  'how': 752,
#  'hand,': 753,
#  'delhi.': 754,
#  'is,': 755,
#  'purchase': 756,
#  'delay': 757,
#  'except': 758,
#  'entire': 759,
#  'say': 760,
#  'framed': 761,
#  '2,': 762,
#  'absence': 763,
#  'art.': 764,
#  'applications': 765,
#  'unless': 766,
#  'husband': 767,
#  'hand': 768,
#  'pending': 769,
#  '(4)': 770,
#  'supply': 771,
#  '25': 772,
#  'gave': 773,
#  'claimant': 774,
#  'fixed': 775,
#  'cr.': 776,
#  'p.m.': 777,
#  '(i)': 778,
#  'plaintiffs': 779,
#  'rate': 780,
#  'above,': 781,
#  'order,': 782,
#  'away': 783,
#  'personal': 784,
#  'declaration': 785,
#  'employees': 786,
#  'request': 787,
#  'presence': 788,
#  'coming': 789,
#  '302': 790,
#  'prescribed': 791,
#  'driver': 792,
#  'permit': 793,
#  'condition': 794,
#  'still': 795,
#  '(supra),': 796,
#  'opinion,': 797,
#  'submission': 798,
#  'interim': 799,
#  'april': 800,
#  'challenged': 801,
#  'nadu': 802,
#  'total': 803,
#  'convicted': 804,
#  'cbi': 805,
#  'amended': 806,
#  'expression': 807,
#  'conduct': 808,
#  'giving': 809,
#  'term': 810,
#  'no.2': 811,
#  'president': 812,
#  'enquiry': 813,
#  'beyond': 814,
#  'namely,': 815,
#  '17': 816,
#  'shows': 817,
#  'lease': 818,
#  'whom': 819,
#  '2008': 820,
#  'interpretation': 821,
#  'caused': 822,
#  'next': 823,
#  'benefit': 824,
#  'extent': 825,
#  'neither': 826,
#  'whole': 827,
#  'applied': 828,
#  'shown': 829,
#  'pvt.': 830,
#  'once': 831,
#  '18': 832,
#  'cited': 833,
#  'december': 834,
#  '2007': 835,
#  'g.': 836,
#  'investigating': 837,
#  'am': 838,
#  'officers': 839,
#  '3,': 840,
#  'urged': 841,
#  'rao': 842,
#  'main': 843,
#  'bar': 844,
#  'means': 845,
#  '2nd': 846,
#  'declared': 847,
#  'bengal': 848,
#  'provide': 849,
#  'allegations': 850,
#  'viz.,': 851,
#  '19': 852,
#  'execution': 853,
#  'regards': 854,
#  'constituted': 855,
#  ':-': 856,
#  'mills': 857,
#  'v': 858,
#  'it.': 859,
#  '(hereinafter': 860,
#  'circumstances,': 861,
#  '(ii)': 862,
#  'awarded': 863,
#  'patna': 864,
#  'secretary': 865,
#  'nath': 866,
#  'anr.': 867,
#  'instant': 868,
#  'development': 869,
#  'manner': 870,
#  'him,': 871,
#  'o.': 872,
#  'several': 873,
#  'charges': 874,
#  'railway': 875,
#  'asked': 876,
#  'properties': 877,
#  'hospital,': 878,
#  'become': 879,
#  'carried': 880,
#  'licence': 881,
#  'five': 882,
#  'pleaded': 883,
#  'kumar,': 884,
#  'finance': 885,
#  'gone': 886,
#  'minimum': 887,
#  'important': 888,
#  'murder': 889,
#  'municipal': 890,
#  'life': 891,
#  'definition': 892,
#  'issues': 893,
#  'bus': 894,
#  'side': 895,
#  'receipt': 896,
#  'university': 897,
#  'whose': 898,
#  'four': 899,
#  'separate': 900,
#  'apply': 901,
#  '2009': 902,
#  'price': 903,
#  'appeared': 904,
#  'object': 905,
#  'conferred': 906,
#  '22': 907,
#  'told': 908,
#  'going': 909,
#  'labour': 910,
#  'mere': 911,
#  'collector': 912,
#  'society': 913,
#  'judgments': 914,
#  'expressed': 915,
#  'evidence,': 916,
#  'informed': 917,
#  'appear': 918,
#  'dead': 919,
#  '21': 920,
#  'specified': 921,
#  'here': 922,
#  'english': 923,
#  '50': 924,
#  'enacted': 925,
#  'law,': 926,
#  'attention': 927,
#  'mysore': 928,
#  'august': 929,
#  'therein': 930,
#  'mean': 931,
#  'just': 932,
#  'july,': 933,
#  'gupta': 934,
#  'march,': 935,
#  'u.p.': 936,
#  'final': 937,
#  'opportunity': 938,
#  'never': 939,
#  '27': 940,
#  'it,': 941,
#  'july': 942,
#  'inter': 943,
#  'foreign': 944,
#  'false': 945,
#  'administrative': 946,
#  'rejected': 947,
#  'college': 948,
#  'appellant.': 949,
#  'direct': 950,
#  'statements': 951,
#  'delivered': 952,
#  'was,': 953,
#  'april,': 954,
#  'i.e.,': 955,
#  'allahabad': 956,
#  'lj': 957,
#  'chapter': 958,
#  'september': 959,
#  'disputes': 960,
#  'tenant': 961,
#  'correct': 962,
#  'fresh': 963,
#  'cross': 964,
#  'old': 965,
#  'code,': 966,
#  'accused,': 967,
#  'lodged': 968,
#  'much': 969,
#  'december,': 970,
#  'arbitration': 971,
#  'know': 972,
#  '1999': 973,
#  'why': 974,
#  'november': 975,
#  'jain': 976,
#  'incident': 977,
#  'i.p.c.': 978,
#  'situated': 979,
#  'arising': 980,
#  'industries': 981,
#  'plea': 982,
#  'constitutional': 983,
#  'minister': 984,
#  'intended': 985,
#  'conducted': 986,
#  'hence,': 987,
#  'imprisonment': 988,
#  '2010': 989,
#  'may,': 990,
#  'sold': 991,
#  'management': 992,
#  'maharashtra': 993,
#  'six': 994,
#  's.c.r.': 995,
#  'agreed': 996,
#  'building': 997,
#  'injury': 998,
#  'joint': 999,
#  'carrying': 1000,
#  ...}

# %% [markdown]
# Assigning NER Word2Vec mapping

# %%
weights_ner_word2vec = np.zeros((vocab_size_ner, 300))

mapping_ner_word2vec = toke.word_index 
mapping_ner_word2vec
# Out:
# {'#UK': 1,
#  'the': 2,
#  'of': 3,
#  'in': 4,
#  'to': 5,
#  'and': 6,
#  'that': 7,
#  'a': 8,
#  'was': 9,
#  'is': 10,
#  'by': 11,
#  'on': 12,
#  'as': 13,
#  'for': 14,
#  'be': 15,
#  'it': 16,
#  'court': 17,
#  'not': 18,
#  'has': 19,
#  'under': 20,
#  'this': 21,
#  'section': 22,
#  'which': 23,
#  'with': 24,
#  'or': 25,
#  'at': 26,
#  'he': 27,
#  'case': 28,
#  'no.': 29,
#  'from': 30,
#  'been': 31,
#  'his': 32,
#  'an': 33,
#  'had': 34,
#  'are': 35,
#  'were': 36,
#  'v.': 37,
#  'state': 38,
#  'also': 39,
#  'have': 40,
#  'act': 41,
#  'order': 42,
#  'any': 43,
#  'no': 44,
#  'high': 45,
#  'accused': 46,
#  'learned': 47,
#  'said': 48,
#  'there': 49,
#  'dated': 50,
#  'supreme': 51,
#  'made': 52,
#  'would': 53,
#  'before': 54,
#  'singh': 55,
#  'held': 56,
#  'who': 57,
#  'such': 58,
#  'against': 59,
#  'other': 60,
#  'but': 61,
#  'their': 62,
#  'one': 63,
#  'if': 64,
#  'respondent': 65,
#  'filed': 66,
#  'appeal': 67,
#  'appellant': 68,
#  'evidence': 69,
#  '&': 70,
#  'all': 71,
#  'only': 72,
#  'decision': 73,
#  'after': 74,
#  'we': 75,
#  'they': 76,
#  'petitioner': 77,
#  'government': 78,
#  'may': 79,
#  'judgment': 80,
#  'act,': 81,
#  'its': 82,
#  'when': 83,
#  'counsel': 84,
#  'view': 85,
#  'same': 86,
#  'application': 87,
#  'india': 88,
#  'out': 89,
#  'can': 90,
#  'further': 91,
#  'petition': 92,
#  'whether': 93,
#  'two': 94,
#  'bench': 95,
#  'stated': 96,
#  'provisions': 97,
#  'question': 98,
#  'her': 99,
#  'law': 100,
#  'cannot': 101,
#  'vs.': 102,
#  'therefore,': 103,
#  'civil': 104,
#  'first': 105,
#  'article': 106,
#  'police': 107,
#  'should': 108,
#  'mr.': 109,
#  '1': 110,
#  'suit': 111,
#  'could': 112,
#  'upon': 113,
#  'will': 114,
#  'these': 115,
#  'taken': 116,
#  'so': 117,
#  'passed': 118,
#  'writ': 119,
#  'rule': 120,
#  'about': 121,
#  'where': 122,
#  'referred': 123,
#  'judge': 124,
#  'being': 125,
#  'him': 126,
#  'given': 127,
#  'even': 128,
#  'i': 129,
#  'kumar': 130,
#  'into': 131,
#  'right': 132,
#  'p.': 133,
#  'present': 134,
#  'per': 135,
#  'ltd.': 136,
#  'rs.': 137,
#  'act.': 138,
#  '2': 139,
#  ':': 140,
#  'air': 141,
#  'time': 142,
#  'criminal': 143,
#  "hon'ble": 144,
#  'constitution': 145,
#  'j.': 146,
#  'delhi': 147,
#  'defendant': 148,
#  'issued': 149,
#  'matter': 150,
#  'shall': 151,
#  'must': 152,
#  'did': 153,
#  'plaintiff': 154,
#  'respect': 155,
#  'she': 156,
#  'statement': 157,
#  'submitted': 158,
#  'company': 159,
#  '3': 160,
#  'case,': 161,
#  'special': 162,
#  'property': 163,
#  's.': 164,
#  'then': 165,
#  'shri': 166,
#  'power': 167,
#  'between': 168,
#  'does': 169,
#  'while': 170,
#  'notice': 171,
#  'tribunal': 172,
#  'within': 173,
#  'above': 174,
#  'date': 175,
#  'trial': 176,
#  'person': 177,
#  'public': 178,
#  'facts': 179,
#  'offence': 180,
#  'sc': 181,
#  'scc': 182,
#  'court,': 183,
#  'having': 184,
#  'however,': 185,
#  'deceased': 186,
#  'tax': 187,
#  'division': 188,
#  'house': 189,
#  'land': 190,
#  'them': 191,
#  'petitioners': 192,
#  'district': 193,
#  'new': 194,
#  '(1)': 195,
#  'code': 196,
#  'apex': 197,
#  'relied': 198,
#  'general': 199,
#  'persons': 200,
#  'down': 201,
#  'officer': 202,
#  'observed': 203,
#  'found': 204,
#  'justice': 205,
#  'court.': 206,
#  'union': 207,
#  'both': 208,
#  '4': 209,
#  'examined': 210,
#  'central': 211,
#  'without': 212,
#  'what': 213,
#  'some': 214,
#  'reference': 215,
#  'though': 216,
#  'came': 217,
#  'sections': 218,
#  'indian': 219,
#  'cases': 220,
#  'another': 221,
#  'jurisdiction': 222,
#  'page': 223,
#  'basis': 224,
#  'claim': 225,
#  'amount': 226,
#  'report': 227,
#  'effect': 228,
#  'up': 229,
#  'part': 230,
#  'possession': 231,
#  'witness': 232,
#  'following': 233,
#  '5': 234,
#  '-': 235,
#  'assessee': 236,
#  'since': 237,
#  'year': 238,
#  'prosecution': 239,
#  'fact': 240,
#  'authority': 241,
#  'bank': 242,
#  'considered': 243,
#  'complainant': 244,
#  'during': 245,
#  'behalf': 246,
#  'three': 247,
#  '(2)': 248,
#  'service': 249,
#  'years': 250,
#  'income': 251,
#  'ram': 252,
#  'regard': 253,
#  '6': 254,
#  'c.': 255,
#  'rules': 256,
#  'placed': 257,
#  'sale': 258,
#  'co.': 259,
#  'reported': 260,
#  'proceedings': 261,
#  'place': 262,
#  'aforesaid': 263,
#  'record': 264,
#  'because': 265,
#  'appellants': 266,
#  'do': 267,
#  'complaint': 268,
#  'registered': 269,
#  'necessary': 270,
#  'additional': 271,
#  'make': 272,
#  'well': 273,
#  'according': 274,
#  'respondents': 275,
#  'ground': 276,
#  'chief': 277,
#  'period': 278,
#  'through': 279,
#  'procedure': 280,
#  'those': 281,
#  'business': 282,
#  'more': 283,
#  'clause': 284,
#  'relevant': 285,
#  '(supra)': 286,
#  'interest': 287,
#  'legal': 288,
#  'mentioned': 289,
#  'our': 290,
#  'favour': 291,
#  'take': 292,
#  'second': 293,
#  'read': 294,
#  'over': 295,
#  'far': 296,
#  'than': 297,
#  'others': 298,
#  'decided': 299,
#  'point': 300,
#  'witnesses': 301,
#  'set': 302,
#  'deposed': 303,
#  'singh,': 304,
#  'pw': 305,
#  'judicial': 306,
#  'ors.': 307,
#  'certain': 308,
#  'consideration': 309,
#  'now': 310,
#  'circumstances': 311,
#  'assessment': 312,
#  'issue': 313,
#  'laid': 314,
#  'terms': 315,
#  'letter': 316,
#  'p.w.': 317,
#  'support': 318,
#  'board': 319,
#  'received': 320,
#  'nos.': 321,
#  'account': 322,
#  'provision': 323,
#  'punjab': 324,
#  'earlier': 325,
#  'insurance': 326,
#  'ex.': 327,
#  'goods': 328,
#  'contention': 329,
#  'corporation': 330,
#  'notification': 331,
#  'commission': 332,
#  '7': 333,
#  'bombay': 334,
#  '8': 335,
#  'india,': 336,
#  'sessions': 337,
#  'took': 338,
#  'party': 339,
#  'r.': 340,
#  'vide': 341,
#  'purpose': 342,
#  'pradesh': 343,
#  'used': 344,
#  'already': 345,
#  'alleged': 346,
#  'recorded': 347,
#  'name': 348,
#  'compensation': 349,
#  'contended': 350,
#  'dr.': 351,
#  '"the': 352,
#  'parties': 353,
#  'clear': 354,
#  'commissioner': 355,
#  'show': 356,
#  'entitled': 357,
#  'us': 358,
#  'directed': 359,
#  'action': 360,
#  'courts': 361,
#  'different': 362,
#  'reliance': 363,
#  'no.1': 364,
#  'office': 365,
#  'admitted': 366,
#  'case.': 367,
#  'decisions': 368,
#  'agreement': 369,
#  'thus': 370,
#  'come': 371,
#  'due': 372,
#  'income-tax': 373,
#  'magistrate': 374,
#  'regarding': 375,
#  'transport': 376,
#  'w.': 377,
#  'granted': 378,
#  'decree': 379,
#  '10': 380,
#  'sri': 381,
#  'k.': 382,
#  'my': 383,
#  'ipc': 384,
#  'motor': 385,
#  'file': 386,
#  'required': 387,
#  'vehicle': 388,
#  'orders': 389,
#  'charge': 390,
#  'paid': 391,
#  'very': 392,
#  'and,': 393,
#  ',': 394,
#  'lal': 395,
#  'payment': 396,
#  'subject': 397,
#  'medical': 398,
#  'exercise': 399,
#  'allowed': 400,
#  'original': 401,
#  'impugned': 402,
#  'opinion': 403,
#  'pay': 404,
#  'investigation': 405,
#  'rights': 406,
#  '.': 407,
#  'powers': 408,
#  'smt.': 409,
#  'contract': 410,
#  'appellate': 411,
#  'observations': 412,
#  'meaning': 413,
#  'a.': 414,
#  'appears': 415,
#  'owner': 416,
#  '9': 417,
#  'way': 418,
#  'nature': 419,
#  '14': 420,
#  'grant': 421,
#  'j.,': 422,
#  'reasonable': 423,
#  'brought': 424,
#  '2.': 425,
#  'itself': 426,
#  'list': 427,
#  'duty': 428,
#  'death': 429,
#  'concerned': 430,
#  'taking': 431,
#  'available': 432,
#  'nor': 433,
#  'third': 434,
#  '12': 435,
#  'copy': 436,
#  'legislature': 437,
#  'therefore': 438,
#  'either': 439,
#  'single': 440,
#  'cr.p.c.': 441,
#  'raised': 442,
#  'again': 443,
#  'full': 444,
#  'find': 445,
#  'judge,': 446,
#  'prasad': 447,
#  'consider': 448,
#  'words': 449,
#  'along': 450,
#  'sh.': 451,
#  'provided': 452,
#  'claimed': 453,
#  'him.': 454,
#  'itr': 455,
#  'documents': 456,
#  'material': 457,
#  'area': 458,
#  'fir': 459,
#  'examination': 460,
#  'station': 461,
#  'each': 462,
#  'village': 463,
#  'clearly': 464,
#  'similar': 465,
#  'holding': 466,
#  'transfer': 467,
#  'pointed': 468,
#  'document': 469,
#  'offences': 470,
#  'penal': 471,
#  'm.': 472,
#  'post': 473,
#  'india.': 474,
#  'n.': 475,
#  'election': 476,
#  'including': 477,
#  '@': 478,
#  'liable': 479,
#  'sub-section': 480,
#  'written': 481,
#  'leave': 482,
#  'based': 483,
#  'information': 484,
#  'appeals': 485,
#  'own': 486,
#  'sent': 487,
#  'hold': 488,
#  'number': 489,
#  'reason': 490,
#  'industrial': 491,
#  'open': 492,
#  'sought': 493,
#  'course': 494,
#  'revenue': 495,
#  'force': 496,
#  'position': 497,
#  'liability': 498,
#  'back': 499,
#  'established': 500,
#  'para': 501,
#  'madras': 502,
#  'parliament': 503,
#  'cit': 504,
#  'true': 505,
#  'affidavit': 506,
#  'statutory': 507,
#  'considering': 508,
#  'entry': 509,
#  '1st': 510,
#  'common': 511,
#  'award': 512,
#  'constitution.': 513,
#  'dismissed': 514,
#  'dispute': 515,
#  'son': 516,
#  'articles': 517,
#  'applicable': 518,
#  'give': 519,
#  'petitions': 520,
#  'advocate': 521,
#  'went': 522,
#  'services': 523,
#  'proved': 524,
#  'cause': 525,
#  'produced': 526,
#  '1,': 527,
#  'defendants': 528,
#  'principles': 529,
#  'kerala': 530,
#  'various': 531,
#  'reasons': 532,
#  'punishable': 533,
#  'merely': 534,
#  'that,': 535,
#  'wife': 536,
#  'result': 537,
#  'working': 538,
#  'b.': 539,
#  'rajasthan': 540,
#  'm/s': 541,
#  'body': 542,
#  'contained': 543,
#  'prior': 544,
#  'scheme': 545,
#  'appearing': 546,
#  '15': 547,
#  'vehicles': 548,
#  'father': 549,
#  '11': 550,
#  'loss': 551,
#  'making': 552,
#  'ld.': 553,
#  'limited': 554,
#  '(3)': 555,
#  'put': 556,
#  '(b)': 557,
#  'conclusion': 558,
#  'concerned,': 559,
#  'member': 560,
#  'use': 561,
#  'amendment': 562,
#  'officer,': 563,
#  'wherein': 564,
#  'registration': 565,
#  'himself': 566,
#  'bearing': 567,
#  'haryana': 568,
#  'relating': 569,
#  'sufficient': 570,
#  'argued': 571,
#  'law.': 572,
#  'recovery': 573,
#  'accepted': 574,
#  'control': 575,
#  'trade': 576,
#  'premises': 577,
#  'left': 578,
#  'crime': 579,
#  'senior': 580,
#  'thus,': 581,
#  'injuries': 582,
#  'family': 583,
#  'committed': 584,
#  'principle': 585,
#  'done': 586,
#  'nothing': 587,
#  'form': 588,
#  'department': 589,
#  '4.': 590,
#  'rent': 591,
#  'ltd.,': 592,
#  '1.': 593,
#  '34': 594,
#  'head': 595,
#  'noted': 596,
#  '(air': 597,
#  'construction': 598,
#  'preferred': 599,
#  'certificate': 600,
#  'committee': 601,
#  'finding': 602,
#  'like': 603,
#  'private': 604,
#  'entered': 605,
#  'chand': 606,
#  'provides': 607,
#  'got': 608,
#  'sum': 609,
#  'particular': 610,
#  'proceeding': 611,
#  'argument': 612,
#  'last': 613,
#  'lord': 614,
#  'national': 615,
#  'settled': 616,
#  'valid': 617,
#  'assistant': 618,
#  'cheque': 619,
#  'members': 620,
#  'treated': 621,
#  'word': 622,
#  'light': 623,
#  '226': 624,
#  '(a)': 625,
#  '"': 626,
#  'towards': 627,
#  'statute': 628,
#  'obtained': 629,
#  'applicant': 630,
#  'magistrate,': 631,
#  'age': 632,
#  'm/s.': 633,
#  'council': 634,
#  'heard': 635,
#  'value': 636,
#  'connection': 637,
#  'appointed': 638,
#  'inspector': 639,
#  'denied': 640,
#  'outside': 641,
#  'drawn': 642,
#  'stage': 643,
#  'note': 644,
#  'follows:': 645,
#  'calcutta': 646,
#  'brother': 647,
#  'every': 648,
#  'see': 649,
#  'intention': 650,
#  'defence': 651,
#  'karnataka': 652,
#  'thereafter': 653,
#  'stand': 654,
#  'u/s': 655,
#  'near': 656,
#  'accident': 657,
#  'deed': 658,
#  'prove': 659,
#  'deputy': 660,
#  'followed': 661,
#  '13': 662,
#  'context': 663,
#  'i.e.': 664,
#  'guilty': 665,
#  'called': 666,
#  'proviso': 667,
#  'lordships': 668,
#  'revision': 669,
#  'doubt': 670,
#  'sentence': 671,
#  'states': 672,
#  'mind': 673,
#  'appointment': 674,
#  'judges': 675,
#  'policy': 676,
#  'accused.': 677,
#  'road': 678,
#  'hearing': 679,
#  'tamil': 680,
#  'dealing': 681,
#  'go': 682,
#  'scope': 683,
#  'bail': 684,
#  'conditions': 685,
#  'proper': 686,
#  '20': 687,
#  'west': 688,
#  'seeking': 689,
#  '(c)': 690,
#  'filing': 691,
#  'them.': 692,
#  'relief': 693,
#  'legislative': 694,
#  'sales': 695,
#  'accordance': 696,
#  'so,': 697,
#  'etc.': 698,
#  'till': 699,
#  'need': 700,
#  'andhra': 701,
#  'aside': 702,
#  'code.': 703,
#  'competent': 704,
#  'fundamental': 705,
#  'day': 706,
#  'specific': 707,
#  '16': 708,
#  'prepared': 709,
#  'under:': 710,
#  'authorities': 711,
#  'madhya': 712,
#  'executed': 713,
#  'hospital': 714,
#  'refer': 715,
#  'purposes': 716,
#  'decide': 717,
#  'raj': 718,
#  'matters': 719,
#  'seen': 720,
#  'sharma': 721,
#  'gujarat': 722,
#  'rules,': 723,
#  'ipc.': 724,
#  'excise': 725,
#  '3.': 726,
#  'reached': 727,
#  'contrary': 728,
#  'rendered': 729,
#  'schedule': 730,
#  'firm': 731,
#  'devi': 732,
#  'limitation': 733,
#  'conviction': 734,
#  'covered': 735,
#  'validity': 736,
#  'acquisition': 737,
#  'chandra': 738,
#  'paragraph': 739,
#  'days': 740,
#  'work': 741,
#  'bihar': 742,
#  'thereafter,': 743,
#  'failed': 744,
#  'get': 745,
#  'appropriate': 746,
#  'review': 747,
#  'direction': 748,
#  'subsequent': 749,
#  'director': 750,
#  'namely': 751,
#  'how': 752,
#  'hand,': 753,
#  'delhi.': 754,
#  'is,': 755,
#  'purchase': 756,
#  'delay': 757,
#  'except': 758,
#  'entire': 759,
#  'say': 760,
#  'framed': 761,
#  '2,': 762,
#  'absence': 763,
#  'art.': 764,
#  'applications': 765,
#  'unless': 766,
#  'husband': 767,
#  'hand': 768,
#  'pending': 769,
#  '(4)': 770,
#  'supply': 771,
#  '25': 772,
#  'gave': 773,
#  'claimant': 774,
#  'fixed': 775,
#  'cr.': 776,
#  'p.m.': 777,
#  '(i)': 778,
#  'plaintiffs': 779,
#  'rate': 780,
#  'above,': 781,
#  'order,': 782,
#  'away': 783,
#  'personal': 784,
#  'declaration': 785,
#  'employees': 786,
#  'request': 787,
#  'presence': 788,
#  'coming': 789,
#  '302': 790,
#  'prescribed': 791,
#  'driver': 792,
#  'permit': 793,
#  'condition': 794,
#  'still': 795,
#  '(supra),': 796,
#  'opinion,': 797,
#  'submission': 798,
#  'interim': 799,
#  'april': 800,
#  'challenged': 801,
#  'nadu': 802,
#  'total': 803,
#  'convicted': 804,
#  'cbi': 805,
#  'amended': 806,
#  'expression': 807,
#  'conduct': 808,
#  'giving': 809,
#  'term': 810,
#  'no.2': 811,
#  'president': 812,
#  'enquiry': 813,
#  'beyond': 814,
#  'namely,': 815,
#  '17': 816,
#  'shows': 817,
#  'lease': 818,
#  'whom': 819,
#  '2008': 820,
#  'interpretation': 821,
#  'caused': 822,
#  'next': 823,
#  'benefit': 824,
#  'extent': 825,
#  'neither': 826,
#  'whole': 827,
#  'applied': 828,
#  'shown': 829,
#  'pvt.': 830,
#  'once': 831,
#  '18': 832,
#  'cited': 833,
#  'december': 834,
#  '2007': 835,
#  'g.': 836,
#  'investigating': 837,
#  'am': 838,
#  'officers': 839,
#  '3,': 840,
#  'urged': 841,
#  'rao': 842,
#  'main': 843,
#  'bar': 844,
#  'means': 845,
#  '2nd': 846,
#  'declared': 847,
#  'bengal': 848,
#  'provide': 849,
#  'allegations': 850,
#  'viz.,': 851,
#  '19': 852,
#  'execution': 853,
#  'regards': 854,
#  'constituted': 855,
#  ':-': 856,
#  'mills': 857,
#  'v': 858,
#  'it.': 859,
#  '(hereinafter': 860,
#  'circumstances,': 861,
#  '(ii)': 862,
#  'awarded': 863,
#  'patna': 864,
#  'secretary': 865,
#  'nath': 866,
#  'anr.': 867,
#  'instant': 868,
#  'development': 869,
#  'manner': 870,
#  'him,': 871,
#  'o.': 872,
#  'several': 873,
#  'charges': 874,
#  'railway': 875,
#  'asked': 876,
#  'properties': 877,
#  'hospital,': 878,
#  'become': 879,
#  'carried': 880,
#  'licence': 881,
#  'five': 882,
#  'pleaded': 883,
#  'kumar,': 884,
#  'finance': 885,
#  'gone': 886,
#  'minimum': 887,
#  'important': 888,
#  'murder': 889,
#  'municipal': 890,
#  'life': 891,
#  'definition': 892,
#  'issues': 893,
#  'bus': 894,
#  'side': 895,
#  'receipt': 896,
#  'university': 897,
#  'whose': 898,
#  'four': 899,
#  'separate': 900,
#  'apply': 901,
#  '2009': 902,
#  'price': 903,
#  'appeared': 904,
#  'object': 905,
#  'conferred': 906,
#  '22': 907,
#  'told': 908,
#  'going': 909,
#  'labour': 910,
#  'mere': 911,
#  'collector': 912,
#  'society': 913,
#  'judgments': 914,
#  'expressed': 915,
#  'evidence,': 916,
#  'informed': 917,
#  'appear': 918,
#  'dead': 919,
#  '21': 920,
#  'specified': 921,
#  'here': 922,
#  'english': 923,
#  '50': 924,
#  'enacted': 925,
#  'law,': 926,
#  'attention': 927,
#  'mysore': 928,
#  'august': 929,
#  'therein': 930,
#  'mean': 931,
#  'just': 932,
#  'july,': 933,
#  'gupta': 934,
#  'march,': 935,
#  'u.p.': 936,
#  'final': 937,
#  'opportunity': 938,
#  'never': 939,
#  '27': 940,
#  'it,': 941,
#  'july': 942,
#  'inter': 943,
#  'foreign': 944,
#  'false': 945,
#  'administrative': 946,
#  'rejected': 947,
#  'college': 948,
#  'appellant.': 949,
#  'direct': 950,
#  'statements': 951,
#  'delivered': 952,
#  'was,': 953,
#  'april,': 954,
#  'i.e.,': 955,
#  'allahabad': 956,
#  'lj': 957,
#  'chapter': 958,
#  'september': 959,
#  'disputes': 960,
#  'tenant': 961,
#  'correct': 962,
#  'fresh': 963,
#  'cross': 964,
#  'old': 965,
#  'code,': 966,
#  'accused,': 967,
#  'lodged': 968,
#  'much': 969,
#  'december,': 970,
#  'arbitration': 971,
#  'know': 972,
#  '1999': 973,
#  'why': 974,
#  'november': 975,
#  'jain': 976,
#  'incident': 977,
#  'i.p.c.': 978,
#  'situated': 979,
#  'arising': 980,
#  'industries': 981,
#  'plea': 982,
#  'constitutional': 983,
#  'minister': 984,
#  'intended': 985,
#  'conducted': 986,
#  'hence,': 987,
#  'imprisonment': 988,
#  '2010': 989,
#  'may,': 990,
#  'sold': 991,
#  'management': 992,
#  'maharashtra': 993,
#  'six': 994,
#  's.c.r.': 995,
#  'agreed': 996,
#  'building': 997,
#  'injury': 998,
#  'joint': 999,
#  'carrying': 1000,
#  ...}

# %% [markdown]
# Fetching weights from pre trained Word2Vec model (ATE)

# %%
for word, index in mapping_ate_word2vec.items():
    if word in word2vec:
        weights_ate_word2vec[index:] = word2vec[word]

# %% [markdown]
# Fetching weights from pre trained Word2Vec model (NER)

# %%
for word, index in mapping_ner_word2vec.items():
    if word in word2vec:
        weights_ner_word2vec[index:] = word2vec[word]

# %% [markdown]
# Initializing the gru Model

# %%
gru_model = Sequential()
gru_model.add(Embedding(input_dim = vocab_size_ate,output_dim = 300,input_length  = 100,weights = [weights_ate_word2vec],trainable = False))
gru_model.add(GRU(64, return_sequences=True))
gru_model.add(TimeDistributed(Dense(Y_padded_train.shape[2], activation='softmax')))
# Out:
# WARNING:tensorflow:From c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %% [markdown]
# Compiling the gru Model

# %%
gru_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['acc',Precision(),Recall()])
# Out:
# WARNING:tensorflow:From c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
gru_f1_callback_val = F1ScoreCallback(data=(X_padded_val, Y_padded_val),name='validation')
gru_f1_callback_train=F1ScoreCallback(data=(X_padded_train, Y_padded_train),name='training')

# %%
gru_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 300)          721800
#
#  gru (GRU)                   (None, 100, 64)           70272
#
#  time_distributed (TimeDist  (None, 100, 4)            260
#  ributed)
#
# =================================================================
# Total params: 792332 (3.02 MB)
# Trainable params: 70532 (275.52 KB)
# Non-trainable params: 721800 (2.75 MB)
# _________________________________________________________________

# %% [markdown]
# Fitting the gru model

# %%
gru_training = gru_model.fit(X_padded_train, Y_padded_train, batch_size=128, epochs=15, validation_data=(X_padded_val, Y_padded_val), callbacks=[gru_f1_callback_train,gru_f1_callback_val])
# Out:
# Epoch 1/15
# WARNING:tensorflow:From c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Shivesh\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 29/29 [==============================] - 2s 31ms/step: 1.3140 - acc: 0.9499 - precision
# training F1 Score: 0.8190506100654602
# 7/7 [==============================] - 0s 34ms/step
# validation F1 Score: 0.8627610802650452
# 8/8 [==============================] - 19s 2s/step - loss: 1.3140 - acc: 0.9499 - precision: 0.9274 - recall: 0.0013 - val_loss: 1.1995 - val_acc: 0.9811 - val_precision: 0.9377 - val_recall: 0.0577
# Epoch 2/15
# 29/29 [==============================] - 1s 42ms/step: 1.1196 - acc: 0.9807 - pr
# training F1 Score: 0.8205118775367737
# 7/7 [==============================] - 0s 36ms/step
# validation F1 Score: 0.8663089871406555
# 8/8 [==============================] - 9s 1s/step - loss: 1.1196 - acc: 0.9807 - precision: 0.9059 - recall: 0.1342 - val_loss: 0.9957 - val_acc: 0.9812 - val_precision: 0.9043 - val_recall: 0.1588
# Epoch 3/15
# 29/29 [==============================] - 2s 68ms/step: 0.8927 - acc: 0.9
# training F1 Score: 0.8154386878013611
# 7/7 [==============================] - 0s 37ms/step
# validation F1 Score: 0.8645381927490234
# 8/8 [==============================] - 14s 2s/step - loss: 0.8927 - acc: 0.9806 - precision: 0.8987 - recall: 0.1636 - val_loss: 0.6781 - val_acc: 0.9803 - val_precision: 0.9017 - val_recall: 0.1638
# Epoch 4/15
# 29/29 [==============================] - 2s 51ms/step: 0.4570 - acc: 0.973
# training F1 Score: 0.5879457592964172
# 7/7 [==============================] - 1s 51ms/step
# validation F1 Score: 0.6447290182113647
# 8/8 [==============================] - 11s 2s/step - loss: 0.4570 - acc: 0.9739 - precision: 0.9721 - recall: 0.8113 - val_loss: 0.2817 - val_acc: 0.9331 - val_precision: 0.9321 - val_recall: 0.9020
# Epoch 5/15
# 29/29 [==============================] - 1s 44ms/step: 0.2379 - acc: 0.9463 -
# training F1 Score: 0.7407200336456299
# 7/7 [==============================] - 0s 49ms/step
# validation F1 Score: 0.8030139803886414
# 8/8 [==============================] - 10s 1s/step - loss: 0.2379 - acc: 0.9463 - precision: 0.9457 - recall: 0.9244 - val_loss: 0.1616 - val_acc: 0.9669 - val_precision: 0.9673 - val_recall: 0.9466
# Epoch 6/15
# 29/29 [==============================] - 1s 47ms/step: 0.1554 - acc: 0.9721
# training F1 Score: 0.7997493743896484
# 7/7 [==============================] - 0s 32ms/step
# validation F1 Score: 0.8411540985107422
# 8/8 [==============================] - 10s 1s/step - loss: 0.1554 - acc: 0.9721 - precision: 0.9720 - recall: 0.9512 - val_loss: 0.1473 - val_acc: 0.9757 - val_precision: 0.9761 - val_recall: 0.9555
# Epoch 7/15
# 29/29 [==============================] - 1s 37ms/step: 0.1386 - acc: 0.9761 - prec
# training F1 Score: 0.7983589172363281
# 7/7 [==============================] - 0s 30ms/step
# validation F1 Score: 0.8405449390411377
# 8/8 [==============================] - 9s 1s/step - loss: 0.1386 - acc: 0.9761 - precision: 0.9761 - recall: 0.9558 - val_loss: 0.1257 - val_acc: 0.9755 - val_precision: 0.9752 - val_recall: 0.9551
# Epoch 8/15
# 29/29 [==============================] - 1s 33ms/step: 0.1217 - acc: 0.9747 - prec
# training F1 Score: 0.7957768440246582
# 7/7 [==============================] - 0s 40ms/step
# validation F1 Score: 0.8382705450057983
# 8/8 [==============================] - 8s 1s/step - loss: 0.1217 - acc: 0.9747 - precision: 0.9747 - recall: 0.9610 - val_loss: 0.1171 - val_acc: 0.9739 - val_precision: 0.9737 - val_recall: 0.9621
# Epoch 9/15
# 29/29 [==============================] - 1s 31ms/step: 0.1142 - acc: 0.9745 - prec
# training F1 Score: 0.7989151477813721
# 7/7 [==============================] - 0s 28ms/step
# validation F1 Score: 0.8406385183334351
# 8/8 [==============================] - 8s 1s/step - loss: 0.1142 - acc: 0.9745 - precision: 0.9747 - recall: 0.9642 - val_loss: 0.1098 - val_acc: 0.9756 - val_precision: 0.9755 - val_recall: 0.9654
# Epoch 10/15
# 29/29 [==============================] - 1s 44ms/step: 0.1078 - acc: 0.9765
# training F1 Score: 0.808695375919342
# 7/7 [==============================] - 0s 43ms/step
# validation F1 Score: 0.8482832908630371
# 8/8 [==============================] - 10s 1s/step - loss: 0.1078 - acc: 0.9765 - precision: 0.9766 - recall: 0.9661 - val_loss: 0.1040 - val_acc: 0.9790 - val_precision: 0.9791 - val_recall: 0.9689
# Epoch 11/15
# 29/29 [==============================] - 1s 34ms/step: 0.1029 - acc: 0.9789 - pr
# training F1 Score: 0.812131404876709
# 7/7 [==============================] - 0s 39ms/step
# validation F1 Score: 0.8589829802513123
# 8/8 [==============================] - 8s 1s/step - loss: 0.1029 - acc: 0.9789 - precision: 0.9789 - recall: 0.9688 - val_loss: 0.1002 - val_acc: 0.9794 - val_precision: 0.9797 - val_recall: 0.9693
# Epoch 12/15
# 29/29 [==============================] - 2s 55ms/step: 0.0993 - acc: 0.9793 -
# training F1 Score: 0.812788724899292
# 7/7 [==============================] - 0s 33ms/step
# validation F1 Score: 0.8631220459938049
# 8/8 [==============================] - 9s 1s/step - loss: 0.0993 - acc: 0.9793 - precision: 0.9793 - recall: 0.9691 - val_loss: 0.0970 - val_acc: 0.9799 - val_precision: 0.9798 - val_recall: 0.9696
# Epoch 13/15
# 29/29 [==============================] - 1s 38ms/step: 0.0960 - acc: 0.9794 - pr
# training F1 Score: 0.812894880771637
# 7/7 [==============================] - 0s 48ms/step
# validation F1 Score: 0.8631517291069031
# 8/8 [==============================] - 8s 1s/step - loss: 0.0960 - acc: 0.9794 - precision: 0.9794 - recall: 0.9692 - val_loss: 0.0938 - val_acc: 0.9800 - val_precision: 0.9798 - val_recall: 0.9697
# Epoch 14/15
# 29/29 [==============================] - 2s 60ms/step: 0.0932 - acc: 0.979
# training F1 Score: 0.8129313588142395
# 7/7 [==============================] - 0s 27ms/step
# validation F1 Score: 0.8631517291069031
# 8/8 [==============================] - 10s 1s/step - loss: 0.0932 - acc: 0.9794 - precision: 0.9794 - recall: 0.9693 - val_loss: 0.0913 - val_acc: 0.9800 - val_precision: 0.9799 - val_recall: 0.9699
# Epoch 15/15
# 29/29 [==============================] - 1s 37ms/step: 0.0909 - acc: 0.9795 - pr
# training F1 Score: 0.8143544793128967
# 7/7 [==============================] - 1s 65ms/step
# validation F1 Score: 0.8627131581306458
# 8/8 [==============================] - 9s 1s/step - loss: 0.0909 - acc: 0.9795 - precision: 0.9796 - recall: 0.9694 - val_loss: 0.0890 - val_acc: 0.9801 - val_precision: 0.9802 - val_recall: 0.9700

# %% [markdown]
# Testing accuracy

# %%
accuracy = gru_model.evaluate(X_padded_test, Y_padded_test, verbose = 1)
print(accuracy[1])
# Out:
# 11/11 [==============================] - 0s 37ms/step - loss: 0.0949 - acc: 0.9780 - precision: 0.9782 - recall: 0.9675
# 0.9779573082923889

# %% [markdown]
# Testing F1 Score

# %%
Y_pred_ate = gru_model.predict(X_padded_test)
real = get_real(Y_padded_test)
pred = get_pred(Y_pred_ate)
f1 = F1Score(average='macro')
f1.update_state(real,pred)
f1_score = f1.result().numpy()
print(f"F1 Score ATE : {f1_score}")
# Out:
# 11/11 [==============================] - 0s 35ms/step
# F1 Score ATE : 0.7290516495704651

# %% [markdown]
# Plotting the graph

# %%
draw_loss_graph(gru_training, "gru Model", gru_f1_callback_train.f1_scores, gru_f1_callback_val.f1_scores)
save_model(gru_model, "gru","Word2Vec","t2")
loaded_model = load_model("Saved_Models/t2_gru_Word2Vec.pkl")
